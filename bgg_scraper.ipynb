# %% [markdown]
# # Web scraper for BBG site
#
# With the help of CHatGPT, chat:
#
# https://chat.openai.com/c/2230ca68-e38b-431c-8eb3-00d84acc69ef
#
# BBG_scraping

# %% [markdown]
# ## Functions

# %%
import requests
import json
from bs4 import BeautifulSoup
import time
import pandas as pd  # Import the pandas library
import re


def filter_func(tag):
    return tag.has_attr('id') and tag['id'].startswith('row_')

def fetch_page_content(url, headers):
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        return response.content
    except requests.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        return None

def parse_html(html_content):
    return BeautifulSoup(html_content, "html.parser")

def extract_game_data(soup, url, rank):
    game_data = {}
    objectid = url.split('/')[-2]

    title_tag = soup.find('title')
    title_text = title_tag.text.split('|')[0] if title_tag else 'Unknown'
    game_data['Title'] = title_text

    json_data_match = re.search(r'GEEK\.geekitemPreload = ({.*?});', str(soup))
    if json_data_match:
        try:
            json_data = json.loads(json_data_match.group(1))
            game_data['Link'] = url
            ## Exploration of data follows Ranking
            game_data['Rank'] = rank  # Store in dictionary 
            # Extract the publishing year
            year_published = json_data.get('item', {}).get('yearpublished', 'Unknown')
            game_data['Year'] = year_published  # Store in dictionary        
            # Extract additional game info
            stats = json_data.get('item', {}).get('stats', {})
            game_data['UsersRated'] = stats.get('usersrated', 'Unknown')
            game_data['AveRating'] = stats.get('average', 'Unknown')
            game_data['Baverage'] = stats.get('baverage', 'Unknown')
            game_data['StdDev'] = stats.get('stddev', 'Unknown')
            game_data['AveWeight'] = stats.get('avgweight', 'Unknown')
            game_data['NumWeights'] = stats.get('numweights', 'Unknown')
            game_data['NumPlays'] = stats.get('numplays', 'Unknown')
            linkcounts = json_data.get('item', {}).get('linkcounts', {})
            game_data['NumAwards'] = linkcounts.get('boardgamehonor', 0)
            polls = json_data.get('item', {}).get('polls', {})
            #print( polls.get('userplayers', 'Unknown')['totalvotes'] )
            game_data['PCountRecomm_min'] = polls.get('userplayers', 'Unknown')['recommended'][0]['min']
            game_data['PCountRecomm_max'] = polls.get('userplayers', 'Unknown')['recommended'][0]['max']
            game_data['PCountBest_min'] = polls.get('userplayers', 'Unknown')['best'][0]['min']
            game_data['PCountBest_max'] = polls.get('userplayers', 'Unknown')['best'][0]['max']
            game_data['PCount_votes'] = polls.get('userplayers', 'Unknown')['totalvotes']
            game_data['MinPlayTime'] = json_data.get('item', {}).get('minplaytime', 'NA')
            game_data['MaxPlayTime'] = json_data.get('item', {}).get('maxplaytime', 'NA')
            mechanics = json_data.get('item', {}).get('links', {}).get('boardgamemechanic', [])
            mechstring = ''
            for i, mech in enumerate(mechanics):
                mechstring += mech['name']
                if i < len(mech)-1:
                    mechstring += '\n'
            game_data['Mechanics'] = mechstring          
            rankinfo = json_data.get('item', {}).get('rankinfo', [])
            for i, rinf in enumerate(rankinfo):
                if rinf['prettyname'] != 'Board Game Rank':
                    game_data['GameCategory_'+str(i)] = rinf['veryshortprettyname']
                    game_data['RankCategory_'+str(i)] = rinf['rank']
                    game_data['ScoreCategory_'+str(i)] = rinf['baverage']          
            rank += 1
        except json.JSONDecodeError as e:
            print(f"JSONDecodeError: {e}")
    else:
        print("JSON data not found in HTML content.")

    # Amazon price extraction logic
    amazon_url = "https://api.geekdo.com/api/amazon/textads"
    params = {"locale": "us", "objectid": objectid, "objecttype": "thing"}
    response = requests.get(amazon_url, params=params)
    if response.status_code == 200:
        amazon_data = response.json()
        if isinstance(amazon_data, dict):  # Check if the response is a dictionary
            price = amazon_data.get('us', {}).get('newprice', 'Unknown')
        else:
            price = 'Unknown'
        game_data['AmazonPrice'] = price
    else:
        game_data['AmazonPrice'] = 'Unknown'

    return game_data

def scrape_boardgame_data(url, headers, rank):
    html_content = fetch_page_content(url, headers)
    if html_content:
        soup = parse_html(html_content)
        return extract_game_data(soup, url, rank)
    else:
        return None

# %% [markdown]
# ## Scrapping for the BGG titles and webpages (This works for 1000 games ONLY)

# %%
import requests
from bs4 import BeautifulSoup
import time


# Initialize an empty list to store the extracted URLs
listurls = []

# Define headers to mimic a real browser request
headers = {'User-Agent': 'Mozilla/6.0'}

# Loop through pages 1 to X
for page_num in range(1, 25):
    URL = f"https://boardgamegeek.com/browse/boardgame/page/{page_num}"
    page = requests.get(URL, headers=headers)
    soup = BeautifulSoup(page.content, "html.parser")

    print(f"HTTP Status Code for page {page_num}: {page.status_code}")

    # Print a snippet of the page content for debugging
    #print("Page content snippet:", soup.text[:500])
    #print(f"HTTP Status Code for page {page_num}: {page.status_code}")

    # Find all instances of elements with id starting with 'row_'
    elements = soup.find_all(filter_func)

    # Loop through each element and find the <a> tags
    for element in elements:
        a_tags = element.find_all('a')
        for a_tag in a_tags:
            # Check if the href attribute exists and follows the specific structure
            if a_tag.has_attr('href') and '/boardgame/' in a_tag['href']:
                url = f"https://boardgamegeek.com{a_tag['href']}"
                # Check for duplicates before appending
                if url not in listurls:
                    listurls.append(url)
    
    # Print the current status
    print(f"Scraping page {page_num} - Total URLs collected: {len(listurls)}")
    
    # Optional: Sleep for a few seconds between requests to avoid overloading the server
    #time.sleep(2)

# Print the total number of extracted URLs
print(f"Total URLs extracted: {len(listurls)}")
# Out:
# HTTP Status Code for page 1: 200
# Scraping page 1 - Total URLs collected: 101
# HTTP Status Code for page 2: 200
# Scraping page 2 - Total URLs collected: 201
# HTTP Status Code for page 3: 200
# Scraping page 3 - Total URLs collected: 302
# HTTP Status Code for page 4: 200
# Scraping page 4 - Total URLs collected: 403
# HTTP Status Code for page 5: 200
# Scraping page 5 - Total URLs collected: 503
# HTTP Status Code for page 6: 200
# Scraping page 6 - Total URLs collected: 603
# HTTP Status Code for page 7: 200
# Scraping page 7 - Total URLs collected: 703
# HTTP Status Code for page 8: 200
# Scraping page 8 - Total URLs collected: 803
# HTTP Status Code for page 9: 200
# Scraping page 9 - Total URLs collected: 903
# HTTP Status Code for page 10: 200
# Scraping page 10 - Total URLs collected: 1004
# HTTP Status Code for page 11: 200
# Scraping page 11 - Total URLs collected: 1004
# HTTP Status Code for page 12: 200
# Scraping page 12 - Total URLs collected: 1004
# HTTP Status Code for page 13: 200
# Scraping page 13 - Total URLs collected: 1004
# HTTP Status Code for page 14: 200
# Scraping page 14 - Total URLs collected: 1004
# HTTP Status Code for page 15: 200
# Scraping page 15 - Total URLs collected: 1004
# HTTP Status Code for page 16: 200
# Scraping page 16 - Total URLs collected: 1004
# HTTP Status Code for page 17: 200
# Scraping page 17 - Total URLs collected: 1004
# HTTP Status Code for page 18: 200
# Scraping page 18 - Total URLs collected: 1004
# HTTP Status Code for page 19: 200
# Scraping page 19 - Total URLs collected: 1004
# HTTP Status Code for page 20: 200
# Scraping page 20 - Total URLs collected: 1004
# HTTP Status Code for page 21: 200
# Scraping page 21 - Total URLs collected: 1004
# HTTP Status Code for page 22: 200
# Scraping page 22 - Total URLs collected: 1004
# HTTP Status Code for page 23: 200
# Scraping page 23 - Total URLs collected: 1004
# HTTP Status Code for page 24: 200
# Scraping page 24 - Total URLs collected: 1004
# Total URLs extracted: 1004

# %% [markdown]
# ## Alternative 2 to get URLs - BGG Ranking Historicals

# %%
## Getting the list of URLS from the official CSV 
## https://gitlab.com/recommend.games/bgg-ranking-historicals/-/tree/master?ref_type=heads

import pandas as pd

df = pd.read_csv('FullBGGData_2024-05-08.csv', sep=',', header=0)
df.head()
# Out:
#        ID                               Name  Year  Rank  Average  \
# 0  224517                  Brass: Birmingham  2018     1     8.60
# 1  161936          Pandemic Legacy: Season 1  2015     2     8.53
# 2  174430                         Gloomhaven  2017     3     8.59
# 3  342942                           Ark Nova  2021     4     8.54
# 4  233078  Twilight Imperium: Fourth Edition  2017     5     8.61
#
#    Bayes average  Users rated  \
# 0          8.416        44997
# 1          8.382        53188
# 2          8.357        61809
# 3          8.333        42308
# 4          8.243        23460
#
#                                                  URL  \
# 0                 /boardgame/224517/brass-birmingham
# 1         /boardgame/161936/pandemic-legacy-season-1
# 2                       /boardgame/174430/gloomhaven
# 3                         /boardgame/342942/ark-nova
# 4  /boardgame/233078/twilight-imperium-fourth-edi...
#
#                                            Thumbnail
# 0  https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg...
# 1  https://cf.geekdo-images.com/-Qer2BBPG7qGGDu6K...
# 2  https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZ...
# 3  https://cf.geekdo-images.com/SoU8p28Sk1s8MSvoM...
# 4  https://cf.geekdo-images.com/_Ppn5lssO5OaildSE...

# %%
baseurl = 'https://boardgamegeek.com'
listurls = df.URL.to_list()
listurls = [baseurl + url for url in listurls]
len(listurls)
# Out:
# 26286

# %% [markdown]
# ## TEST

# %%
headers = {'User-Agent': 'Mozilla/6.0'}

credits = listurls[0]+'/credits#boardgamemechanic'
html_content = fetch_page_content(credits, headers)

if html_content:
        soup = parse_html(html_content)
json_data_match = re.search(r'GEEK\.geekitemPreload = ({.*?});', str(soup))
json_data = json.loads(json_data_match.group(1))
mechanics = json_data.get('item', {}).get('links', {}).get('boardgamemechanic', [])
print(mechanics)
soup
#urlcredits = listurls[0]+'/credits'
#print(urlcredits)
#html_content = fetch_page_content(urlcredits, headers)
#soup = parse_html(html_content)
#soup
# Out:
# [{'name': 'Hand Management', 'sortindex': '1', 'objecttype': 'property', 'objectid': '2040', 'primarylink': 0, 'itemstate': 'approved', 'href': '/boardgamemechanic/2040/hand-management', 'canonical_link': 'https://boardgamegeek.com/boardgamemechanic/2040/hand-management'}, {'name': 'Income', 'sortindex': '1', 'objecttype': 'property', 'objectid': '2902', 'primarylink': 0, 'itemstate': 'approved', 'href': '/boardgamemechanic/2902/income', 'canonical_link': 'https://boardgamegeek.com/boardgamemechanic/2902/income'}, {'name': 'Loans', 'sortindex': '1', 'objecttype': 'property', 'objectid': '2904', 'primarylink': 0, 'itemstate': 'approved', 'href': '/boardgamemechanic/2904/loans', 'canonical_link': 'https://boardgamegeek.com/boardgamemechanic/2904/loans'}, {'name': 'Market', 'sortindex': '1', 'objecttype': 'property', 'objectid': '2900', 'primarylink': 0, 'itemstate': 'approved', 'href': '/boardgamemechanic/2900/market', 'canonical_link': 'https://boardgamegeek.com/boardgamemechanic/2900/market'}, {'name': 'Network and Route Building', 'sortindex': '1', 'objecttype': 'property', 'objectid': '2081', 'primarylink': 0, 'itemstate': 'approved', 'href': '/boardgamemechanic/2081/network-and-route-building', 'canonical_link': 'https://boardgamegeek.com/boardgamemechanic/2081/network-and-route-building'}, {'name': 'Tags', 'sortindex': '1', 'objecttype': 'property', 'objectid': '3100', 'primarylink': 0, 'itemstate': 'approved', 'href': '/boardgamemechanic/3100/tags', 'canonical_link': 'https://boardgamegeek.com/boardgamemechanic/3100/tags'}]
# <!DOCTYPE html>
#
# <html lang="en-US" ng-app="GeekApp" ng-cloak="">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" id="vp" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Brass: Birmingham | Board Game | BoardGameGeek</title>
# <link href="https://boardgamegeek.com/boardgame/224517/brass-birmingham" rel="canonical"/>
# <link href="https://cf.geekdo-static.com/icons/touch-icon180.png" rel="apple-touch-icon"/>
# <link href="https://cf.geekdo-static.com/icons/favicon2.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://cf.geekdo-static.com/icons/favicon2.ico" rel="icon" type="image/ico"/>
# <link href="/game-opensearch.xml" rel="search" title="BGG Game Search" type="application/opensearchdescription+xml"/>
# <meta content="BGG" name="apple-mobile-web-app-title"/>
# <meta content="#2e2b47" name="theme-color"/>
# <link href="https://api.geekdo.com" rel="preconnect"/>
# <link as="image" href="https://cf.geekdo-images.com/e2e0wdO8oVNzD0ZAhzi6MQ__itemheader/img/Zj1GBUN2m-z4zX2-QWn31fiKEE4=/800x450/filters:quality(30):strip_icc()/pic3509697.jpg" media="(min-width: 768px)" rel="preload"/>
# <link as="image" href="https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__itemrep/img/giNUMut4HAl-zWyQkGG0YchmuLI=/fit-in/246x300/filters:strip_icc()/pic3490053.jpg" rel="preload"/>
# <meta content="Brass: Birmingham" name="title"/>
# <meta content="https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__opengraph/img/9JP25fFDv5TUeo3h0i2ky6xXwQk=/0x249:1200x879/fit-in/1200x630/filters:strip_icc()/pic3490053.jpg" property="og:image">
# <meta content="Brass: Birmingham" property="og:title">
# <meta content="BoardGameGeek" property="og:site_name">
# <meta content="https://boardgamegeek.com/boardgame/224517/brass-birmingham" property="og:url">
# <meta content="website" property="og:type">
# <meta content="Build networks, grow industries, and navigate the world of the Industrial Revolution." property="og:description">
# <meta content="summary_large_image" name="twitter:card">
# <meta content="Brass: Birmingham" name="twitter:title"/>
# <meta content="https://cf.geekdo-images.com/x3zxjr-Vw5iU4yDPg70Jgw__opengraph/img/9JP25fFDv5TUeo3h0i2ky6xXwQk=/0x249:1200x879/fit-in/1200x630/filters:strip_icc()/pic3490053.jpg" name="twitter:image:src"/>
# <meta content="Build networks, grow industries, and navigate the world of the Industrial Revolution." name="twitter:description"/>
# <meta content="Build networks, grow industries, and navigate the world of the Industrial Revolution." name="description"/>
# <meta content="board game, boardgames, boardgame, board, games, game, hobby, boardgamegeek, geek, geekdo" name="keywords"/>
# <script>window.AdSlots = window.AdSlots || {
# 	cmd: [],
# 	disableScripts: ['gpt'],
# 	renderOnFirstLoad: false,
# 	divCheck: false
# };</script>
# <link href="https://cf.geekdo-static.com/static/geekui_master2_664678210f50c.css" rel="stylesheet" type="text/css"/>
# <base href="/"/>
# <script crossorigin="anonymous" src="https://kit.fontawesome.com/ece5b35462.js"></script>
# <script>
# 	var GEEK = GEEK || {};
# 	GEEK.adBlock = {"blockleaderboard":0,"blocklargeleaderboard":0,"blockskyscraper":0,"blockrectangle":0,"blockitembanner":0,"blocktextad":0,"blockebay":0,"blocksupportdrive":0,"blockamazon":0,"blockamazonsearch":0,"blockcontestsmodule":0,"blockbggstore":0,"blockbuyacopy":0,"blockpreview":0,"blockbetweenposts":0,"blocksleevesad":0};
# 	GEEK.adConfig = {"blockleaderboard":false,"blockskyscraper":false,"noadsense":false};
# 	GEEK.adSlots = {"dfp-leaderboard":{"name":"boardgame_leaderboard_728x90"},"dfp-skyscraper":{"name":"boardgame_skyscraper_160x600"},"dfp-medrect":{"name":"boardgame_rectangle_300x250"},"dfp-repeater":{"name":"boardgame_home_repeater"},"dfp-medrect-reserved-home":{"name":"boardgame_reserved_home_300x250"},"dfp-leaderboard-lg":{"name":"boardgame_home_hero"},"dfp-home-sidekick":{"name":"boardgame_home_repeater"},"dfp-inline-post":{"name":"boardgame_inline_post"}};
# 	GEEK.legacyAds = [];
# 	GEEK.bggStoreAds = [];
# 	GEEK.googleTargets = {"gameid":["224517"],"companyid":["21765","3475","44580","25074","21608","11043","34522","31071","8832","8820","4785","42147","36210","46500","30677","36186","7466","41423","4932","54777"],"temp_co":["hot","hot","hot"],"familyid":["83784","61830","61842","61831","55549","55559","55718","55547","64690","64689","64680","64681","64679","73364","58912","74286","56191","65041","66892","66899","66898","17519","81601","65191","14759","8374","22135","77349","70948","81575","26397","57499","50152","59705","78198","81586","4705","5497","66445"],"propertyid":["2726","1021","2040","2902","1088","2904","2900","2081","2710","3100","2849","1034","1011","2826","2897"],"personid":["32887","32887","70571","70568","38179","32943","32943","6"],"temp_ppl":["hot"],"temp_game":["hot"]};
# 	GEEK.userid = 0;
# 	GEEK.domainname = 'boardgamegeek.com';
# 	GEEK.domain = 'boardgame';
# 	GEEK.geekitemPreload = {"item":{"itemdata":[{"datatype":"geekitem_fielddata","fieldname":"name","title":"Primary Name","primaryname":true,"required":true,"unclickable":true,"fullcredits":true,"subtype":"boardgame","keyname":"name"},{"datatype":"geekitem_fielddata","fieldname":"alternatename","title":"Alternate Names","alternate":true,"unclickable":true,"fullcredits":true,"subtype":"boardgame","keyname":"alternatename"},{"datatype":"geekitem_fielddata","fieldname":"yearpublished","title":"Year Released","fullcredits":true,"subtype":"boardgame","keyname":"yearpublished"},{"datatype":"geekitem_fielddata","fieldname":"minplayers","title":"Minimum Players","subtype":"boardgame","keyname":"minplayers"},{"datatype":"geekitem_fielddata","fieldname":"maxplayers","title":"Maximum Players","subtype":"boardgame","keyname":"maxplayers"},{"datatype":"geekitem_fielddata","fieldname":"minplaytime","title":"Minimum Playing Time","createposttext":" minutes","posttext":" minutes","subtype":"boardgame","keyname":"minplaytime"},{"datatype":"geekitem_fielddata","fieldname":"maxplaytime","title":"Maximum Playing Time","createposttext":" minutes","posttext":" minutes","subtype":"boardgame","keyname":"maxplaytime"},{"datatype":"geekitem_fielddata","fieldname":"minage","title":"Mfg Suggested Ages","createtitle":"Minimum Age","posttext":" and up","subtype":"boardgame","keyname":"minage"},{"datatype":"geekitem_fielddata","fieldname":"override_rankable","title":"Override Rankable","table":"geekitem_items","options":[{"value":1,"title":"yes"},{"value":0,"title":"no"}],"adminonly":true,"subtype":"boardgame","keyname":"override_rankable"},{"datatype":"geekitem_fielddata","fieldname":"targetco_url","unclickable":true,"title":"Target Co Order Link","subtype":"boardgame","keyname":"targetco_url"},{"datatype":"geekitem_fielddata","fieldname":"walmart_id","unclickable":true,"title":"Walmart Item Id","nullable":true,"subtype":"boardgame","keyname":"walmart_id"},{"datatype":"geekitem_fielddata","fieldname":"instructional_videoid","unclickable":true,"title":"Promoted Instructional Video ID","validatemethod":"ValidateVideoid","nullable":true,"subtype":"boardgame","keyname":"instructional_videoid"},{"datatype":"geekitem_fielddata","fieldname":"summary_videoid","unclickable":true,"title":"Promoted Summary Video ID","validatemethod":"ValidateVideoid","nullable":true,"subtype":"boardgame","keyname":"summary_videoid"},{"datatype":"geekitem_fielddata","fieldname":"playthrough_videoid","unclickable":true,"title":"Promoted Playthrough Video ID","validatemethod":"ValidateVideoid","nullable":true,"subtype":"boardgame","keyname":"playthrough_videoid"},{"datatype":"geekitem_fielddata","fieldname":"focus_videoid","unclickable":true,"title":"Promoted In Focus Video ID","validatemethod":"ValidateVideoid","nullable":true,"subtype":"boardgame","keyname":"focus_videoid"},{"datatype":"geekitem_fielddata","fieldname":"howtoplay_videoid","unclickable":true,"title":"Promoted BGG How to Play Video ID","validatemethod":"ValidateVideoid","nullable":true,"subtype":"boardgame","keyname":"howtoplay_videoid"},{"datatype":"geekitem_fielddata","fieldname":"bggstore_product","unclickable":true,"title":"Promoted BGG Store Product Name","nullable":true,"subtype":"boardgame","keyname":"bggstore_product"},{"datatype":"geekitem_fielddata","fieldname":"short_description","title":"Short Description","table":"geekitem_items","maxlength":85,"editfieldsize":60,"required":true,"subtype":"boardgame","keyname":"short_description"},{"datatype":"geekitem_linkdata","other_objecttype":"person","other_subtype":"boardgamedesigner","linktype":"boardgamedesigner","self_prefix":"src","title":"Designer","titlepl":"Designers","fullcredits":true,"schema":{"itemprop":"creator","itemtype":"https:\/\/schema.org\/Person"},"keyname":"boardgamedesigner"},{"datatype":"geekitem_linkdata","other_objecttype":"person","other_subtype":"boardgamesolodesigner","linktype":"boardgamesolodesigner","self_prefix":"src","title":"Solo Designe ...
# 	GEEK.geekitemSettings = {"fluidlayout":false,"absolutedates":false,"fulldescriptions":false,"overview_nohot":false,"recentitems_showcount":5,"modules":{"boardgameperson":[{"name":"description","enabled":true}],"boardgame":[{"name":"promotedvideos","enabled":true},{"name":"media","enabled":true},{"name":"description","enabled":true},{"name":"awards","enabled":true},{"name":"marketplace","adblock":"blockbuyacopy","enabled":true},{"name":"sleeves_ad","adblock":"blocksleevesad","enabled":true},{"name":"videos","enabled":true},{"name":"reviews","enabled":true},{"name":"recs","enabled":true},{"name":"forums","enabled":true},{"name":"files","enabled":true},{"name":"wiki","enabled":true},{"name":"moregame","enabled":true}]}};
# 	GEEK.geekitemModules = {"media":{"name":"media","html":"<media-module><\/media-module>","prettyname":"Images"},"promotedvideos":{"name":"promotedvideos","html":"<promotedvideos-module geekitem=\"overviewctrl.geekitem\"><\/promotedvideos-module>","prettyname":"Promoted Videos"},"classification":{"name":"classification","html":"<classifications-module geekitem=\"overviewctrl.geekitem\"><\/classifications-module>","prettyname":"Classification"},"description":{"name":"description","html":"<description-module wikitext=\"overviewctrl.geekitem.data.item.description\" geekitem=\"overviewctrl.geekitem\"><\/description-module>","prettyname":"Description"},"marketplace":{"name":"marketplace","html":"<marketplace-module geekitem=\"overviewctrl.geekitem\"><\/marketplace-module>","prettyname":"Marketplace"},"sleeves_ad":{"name":"sleeves_ad","html":"<sleeves-ad-module geekitem=\"overviewctrl.geekitem\"><\/sleeves-ad-module>","prettyname":"Sleeves Ad"},"videos":{"name":"videos","html":"<span class='hidden-xs'>\n\t\t\t\t\t\t\t\t\t\t\t<videos-overview-module ng-if='!overviewctrl.geekitemSettings.overview_nohot'><\/videos-overview-module>\n\t\t\t\t\t\t\t\t\t\t\t<videos-overview-module-recent ng-if='overviewctrl.geekitemSettings.overview_nohot'><\/videos-overview-module-recent>\n\t\t\t\t\t\t\t\t\t <\/span>","prettyname":"Videos"},"reviews":{"name":"reviews","html":"<reviews-module disablelocation=\"true\"><\/reviews-module>","prettyname":"Reviews"},"forums":{"name":"forums","html":"<forums-overview-module disablelocation=\"true\"><\/forums-overview-module>","prettyname":"Forums"},"recs":{"name":"recs","html":"<recs-module-overview><\/recs-module-overview>","prettyname":"Recommended Games"},"files":{"name":"files","html":"<files-overview-module disablelocation=\"true\"><\/files-overview-module>","prettyname":"Files"},"wiki":{"name":"wiki","html":"<wiki-module wikitext=\"overviewctrl.geekitem.data.item.wiki\"><\/wiki-module>","prettyname":"Wiki"},"moregame":{"name":"moregame","html":"<more-game-module geekitem=\"overviewctrl.geekitem\"><\/more-game-module>","prettyname":"More of this Game"}};
# 	GEEK.geekGlobalSettings = {"shutdown_file_ops":"1","shutdown_storeimage_ops":"0","shutdown_edit_avatar":"0","shutdown_file_upload":"0","shutdown_file_download":"0","shutdown_image_upload":"0"};
# 	GEEK.geekimageSettings = {"galleries":{"all":{"name":"all","prettyname":"All","description":""},"game":{"name":"game","prettyname":"Game","description":" Images where the focus is on the unaltered game, box, and\/or components."},"people":{"name":"people","prettyname":"People","description":"Images where people are prominently featured with the game."},"creative":{"name":"creative","prettyname":"Creative","description":"Images of the game that contain creative elements such as modified components (including custom painted miniatures), fun situations, storage solutions, screen shots of online implementations, advertisements, prototypes, or artwork. Any images where the game has been added to or altered."}}};
# 	GEEK.legacy = 0;
# 	GEEK.apiurlsPrefix = 'https://api.geekdo.com';
#
#
#
# 		GEEK.apiurls = {
# 		'root': '/api',
# 		'amazon': '/api/amazon',
# 		'files': '/api/files',
# 		'geekitems': '/api/geekitems',
# 		'collectionstatsgraph': '/api/collectionstatsgraph',
# 		'images': '/api/images',
# 		'threads': '/api/forums/threads',
# 	 	'forums': '/api/forums',
# 		'videos': '/api/videos',
# 		'hotness': '/api/hotness',
# 		'dynamicinfo': '/api/dynamicinfo',
# 		'subtypeinfo': '/api/subtypeinfo',
# 		'geekbay': '/api/geekbay',
# 		'geekmarket': '/market/api/v1',
# 	    'geekmarketapi': '/api/market',
# 		'geeklists': '/api/geeklists',
# 		'reviews': '/api/forumreviews',
# 		'collections': '/api/collections',
# 		'linkeditems': '/api/geekitem/linkeditems',
# 		'subscriptions': '/api/subscriptions',
# 	    'fans': '/api/fans',
# 	    'geekpreviews': '/api/geekpreviews',
# 	    'geekpreviewitems': '/api/geekpreviewitems',
# 	   	'geekpreviewparentitems': '/api/geekpreviewparentitems',
# 		'recs': '/api/geekitem/recs',
# 	    'awards': '/api/geekawards',
# 		'historicalrankgraph':  '/api/historicalrankgraph',
# 		'blueprint_recipes': '/api/blueprints/recipes',
# 		'affiliateads' : '/api/affiliateads',
# 		'sleevesbycard': '/api/sleevesbycard',
# 		'cardsetsbygame': '/api/cardsetsbygame',
# 	};
# </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-104725-1"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
# 	gtag('consent', 'default', {
# 		'ad_storage': 'denied',
# 		'analytics_storage': 'denied',
# 		'personalization_storage': 'denied',
# 		'wait_for_update': 3000
# 		 });
# 	gtag('config', 'UA-104725-1', {
# 		'cookie_domain': 'boardgamegeek.com',
# 		'send_page_view': false
# 	});
# </script>
# <script src="https://cf.geekdo-static.com/static/geekangular17_master2_6646783069786.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/geekui_master2_664678210f50c.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/geekitem_master2_66467820e7be1.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/geekcollection_master2_664678305f3d1.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/geekoutputtemplates_master2_6646783145369.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/geekitemtemplates_master2_66467831520ef.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/geekcollectiontemplates_master2_6646783190cb8.js" type="text/javascript"></script>
# <script src="https://cf.geekdo-static.com/static/geekuicommontemplates_master2_664678314e55b.js" type="text/javascript"></script>
# <script>
# 	window.geekCookieConsent.gtagReady.then(function() {
# 		gtag('event', 'page_view');
# 	});
# </script>
# </meta></meta></meta></meta></meta></meta></meta></head>
# <body class="domain-boardgame" ng-class="{ 'has-no-max-width' : layoutctrl.geekitemSettings.fluidlayout }" ng-controller="GeekOutput_LayoutCtrl as layoutctrl">
# <div class="d-flex flex-column min-vh-100">
# <div class="global-header-outer" click-out="navctrl.closeMobileMenu()" id="global-header-outer" ng-controller="NavCtrl as navctrl">
# <geeknav-menu></geeknav-menu>
# </div>
# <main class="global-body flex-grow-1" id="mainbody" ng-class="{ 'has-overlay-sidebar': layoutctrl.showOverlaySidebar, 'has-hidden-fixed-sidebar': layoutctrl.localStorage.hideFixedSidebar }">
# <a id="mainbodytarget" tabindex="-1"></a>
# <!-- Home King Ad -->
# <div class="item-hero-layout" hide-ad-block="blockleaderboard">
# <div class="advertisement-leaderboard">
# <div class="center-block" ng-dfp-ad="dfp-leaderboard"></div>
# </div>
# </div>
# <div class="global-body-content-container container-fluid">
# <geekoutput-sidebar deactivate-overlay-sidebar="layoutctrl.deactivateOverlaySidebar" show-overlay-sidebar="layoutctrl.showOverlaySidebar"></geekoutput-sidebar>
# <div class="global-body-content pending" ng-class="{'ready': layoutctrl.ready}">
# <a id="maincontenttarget" tabindex="-1"></a>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/highcharts/8.2.2/highstock.src.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/highcharts/8.2.2/modules/accessibility.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/highcharts/8.2.2/themes/sand-signika.min.js"></script>
# <geekitem linkshowcount="6" subtype="boardgame"></geekitem>
# <div class="global-body-content-secondary">
# </div>
# </div>
# </div>
# </main>
# <geekoutput-footer></geekoutput-footer>
# </div>
# </body>
# </html>

# %%
len(listurls)
# Out:
# 26286

# %%
data_list = []
rank = 1
for i, url in enumerate(listurls):
    if i < 3000:
        game_data = scrape_boardgame_data(url, headers, rank)
        if game_data:
            data_list.append(game_data)
            rank += 1
df = pd.DataFrame(data_list)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 5
#       3 for i, url in enumerate(listurls):
#       4     if i < 3000:
# ----> 5         game_data = scrape_boardgame_data(url, headers, rank)
#       6         if game_data:
#       7             data_list.append(game_data)
#
# Cell In[4], line 98, in scrape_boardgame_data(url, headers, rank)
#      97 def scrape_boardgame_data(url, headers, rank):
# ---> 98     html_content = fetch_page_content(url, headers)
#      99     if html_content:
#     100         soup = parse_html(html_content)
#
# Cell In[4], line 14, in fetch_page_content(url, headers)
#      12 def fetch_page_content(url, headers):
#      13     try:
# ---> 14         response = requests.get(url, headers=headers)
#      15         response.raise_for_status()
#      16         return response.content
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/sessions.py:725, in Session.send(self, request, **kwargs)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/sessions.py:725, in <listcomp>(.0)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1390, in HTTPConnection.getresponse(self)
#    1388 try:
#    1389     try:
# -> 1390         response.begin()
#    1391     except ConnectionError:
#    1392         self.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(data_list)
df
# Out:
#                                    Title  \
# 0                     Brass: Birmingham
# 1             Pandemic Legacy: Season 1
# 2                            Gloomhaven
# 3                              Ark Nova
# 4     Twilight Imperium: Fourth Edition
# ...                                  ...
# 2293                           Autobahn
# 2294                       GoodCritters
# 2295                      We the People
# 2296             Founders of Gloomhaven
# 2297                      League of Six
#
#                                                    Link  Rank  Year  \
# 0     https://boardgamegeek.com/boardgame/224517/bra...     1  2018
# 1     https://boardgamegeek.com/boardgame/161936/pan...     2  2015
# 2     https://boardgamegeek.com/boardgame/174430/glo...     3  2017
# 3     https://boardgamegeek.com/boardgame/342942/ark...     4  2021
# 4     https://boardgamegeek.com/boardgame/233078/twi...     5  2017
# ...                                                 ...   ...   ...
# 2293  https://boardgamegeek.com/boardgame/348554/aut...  2294  2022
# 2294  https://boardgamegeek.com/boardgame/255615/goo...  2295  2018
# 2295  https://boardgamegeek.com/boardgame/620/we-people  2296  1993
# 2296  https://boardgamegeek.com/boardgame/214032/fou...  2297  2018
# 2297  https://boardgamegeek.com/boardgame/31624/leag...  2298  2007
#
#      UsersRated AveRating Baverage   StdDev AveWeight NumWeights  ...  \
# 0         45176   8.59882  8.41597  1.41467    3.8814       2184  ...
# 1         53263   8.52865  8.38135   1.5974    2.8308       1448  ...
# 2         61887   8.59213   8.3562  1.73926    3.9099       2553  ...
# 3         42599   8.53609  8.33362  1.38106    3.7568       2237  ...
# 4         23551   8.60338   8.2422  1.61956    4.3125       1152  ...
# ...         ...       ...      ...      ...       ...        ...  ...
# 2293       1468   7.09098   6.1301  1.45403    3.8252        103  ...
# 2294       1545   7.01845  6.13193  1.30045    1.4545         33  ...
# 2295       1148   7.30502  6.12896  1.44088    2.7034        145  ...
# 2296       3136   6.60502  6.12989  1.73012    4.1122        205  ...
# 2297       1954   6.79101  6.12897  1.27722     2.885        200  ...
#
#      GameCategory_1  RankCategory_1  ScoreCategory_1  AmazonPrice  \
# 0         Strategy                1          8.43294       $70.45
# 1          Thematic               1           8.3821       $71.98
# 2          Thematic               2          8.33583      $300.99
# 3         Strategy                3          8.34558       $62.82
# 4          Thematic               3          8.26259      $131.99
# ...             ...             ...              ...          ...
# 2293      Strategy             1090            6.268       $51.01
# 2294         Party              104          6.52474       $20.89
# 2295           War              172          6.96794      Unknown
# 2296      Strategy             1162           6.2101       $49.95
# 2297      Strategy             1117          6.24706       $55.00
#
#       GameCategory_2  RankCategory_2 ScoreCategory_2 GameCategory_3  \
# 0                NaN             NaN             NaN            NaN
# 1          Strategy                2         8.36925            NaN
# 2          Strategy                4         8.31822            NaN
# 3                NaN             NaN             NaN            NaN
# 4          Strategy                5         8.26533            NaN
# ...              ...             ...             ...            ...
# 2293             NaN             NaN             NaN            NaN
# 2294             NaN             NaN             NaN            NaN
# 2295             NaN             NaN             NaN            NaN
# 2296             NaN             NaN             NaN            NaN
# 2297             NaN             NaN             NaN            NaN
#
#      RankCategory_3 ScoreCategory_3
# 0               NaN             NaN
# 1               NaN             NaN
# 2               NaN             NaN
# 3               NaN             NaN
# 4               NaN             NaN
# ...             ...             ...
# 2293            NaN             NaN
# 2294            NaN             NaN
# 2295            NaN             NaN
# 2296            NaN             NaN
# 2297            NaN             NaN
#
# [2298 rows x 30 columns]

# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import sys
import pandas as pd  # Import the pandas library

# Initialize an empty list to store the data
data_list = []

# Sample list of URLs (replace with your actual list of 2003 URLs)
#listurls = ['https://boardgamegeek.com/boardgame/161936/pandemic-legacy-season-1']

# Sample headers (replace with your actual headers)
headers = {'User-Agent': 'Mozilla/5.0'}

rank = 1

sublisturls = listurls[:5000]

for url in sublisturls:
    # Initialize a dictionary to store the data for each game
    game_data = {}
    
    page = requests.get(url, headers=headers)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract objectid from the URL
    objectid = url.split('/')[-2]

    # Title
    title_tag = soup.find('title')
    title_text = title_tag.text.split('|')[0] if title_tag else 'Unknown'
    game_data['Title'] = title_text  # Store in dictionary
    
    # Year published
    json_data_match = re.search(r'GEEK\.geekitemPreload = ({.*?});', str(soup))
    
    # Parse the JSON data if found
    if json_data_match:
        json_data_str = json_data_match.group(1)
        
        try:
            json_data = json.loads(json_data_str)
            
            game_data['Link'] = url

            ## Exploration of data follows Ranking
            game_data['Rank'] = rank  # Store in dictionary 

            # Extract the publishing year
            year_published = json_data.get('item', {}).get('yearpublished', 'Unknown')
            game_data['Year'] = year_published  # Store in dictionary
            
            # Extract additional game info
            stats = json_data.get('item', {}).get('stats', {})
            game_data['UsersRated'] = stats.get('usersrated', 'Unknown')
            game_data['AveRating'] = stats.get('average', 'Unknown')
            game_data['Baverage'] = stats.get('baverage', 'Unknown')
            game_data['StdDev'] = stats.get('stddev', 'Unknown')
            game_data['AveWeight'] = stats.get('avgweight', 'Unknown')
            game_data['NumWeights'] = stats.get('numweights', 'Unknown')
            game_data['NumPlays'] = stats.get('numplays', 'Unknown')
            
            linkcounts = json_data.get('item', {}).get('linkcounts', {})
            game_data['NumAwards'] = linkcounts.get('boardgamehonor', 0)

            polls = json_data.get('item', {}).get('polls', {})
            #print( polls.get('userplayers', 'Unknown')['totalvotes'] )
            game_data['PCountRecomm_min'] = polls.get('userplayers', 'Unknown')['recommended'][0]['min']
            game_data['PCountRecomm_max'] = polls.get('userplayers', 'Unknown')['recommended'][0]['max']
            game_data['PCountBest_min'] = polls.get('userplayers', 'Unknown')['best'][0]['min']
            game_data['PCountBest_max'] = polls.get('userplayers', 'Unknown')['best'][0]['max']
            game_data['PCount_votes'] = polls.get('userplayers', 'Unknown')['totalvotes']

            game_data['MinPlayTime'] = json_data.get('item', {}).get('minplaytime', 'NA')
            game_data['MaxPlayTime'] = json_data.get('item', {}).get('maxplaytime', 'NA')

            mechanics = json_data.get('item', {}).get('links', {}).get('boardgamemechanic', [])
            mechstring = ''
            for i, mech in enumerate(mechanics):
                mechstring += mech['name']
                if i < len(mech)-1:
                    mechstring += '\n'
            game_data['Mechanics'] = mechstring
            
            rankinfo = json_data.get('item', {}).get('rankinfo', [])
            for i, rinf in enumerate(rankinfo):
                if rinf['prettyname'] != 'Board Game Rank':
                    game_data['Category_'+str(i)] = rinf['veryshortprettyname']
                    game_data['RankCat_'+str(i)] = rinf['rank']
                    game_data['ScoreCat_'+str(i)] = rinf['baverage']
            
            rank += 1
        except json.JSONDecodeError as e:
            print(f"JSONDecodeError: {e}")
    else:
        print("JSON data not found in HTML content.")
    
    ############## AMAZON price ##############
    # Define the base URL and parameters for Amazon price
    amazon_url = "https://api.geekdo.com/api/amazon/textads"
    params = {
        "locale": "us",
        "objectid": objectid,
        "objecttype": "thing"
    }
    # Make a request to the Amazon API endpoint
    response = requests.get(amazon_url, params=params)
    if response.status_code == 200:
        amazon_data = response.json()
        if isinstance(amazon_data, dict):  # Check if the response is a dictionary
            price = amazon_data.get('us', {}).get('newprice', 'Unknown')
        else:
            price = 'Unknown'
        game_data['AmazonPrice'] = price

    else:
        game_data['AmazonPrice'] = 'Unknown'
    ############################################

    # Append the game data to the list
    data_list.append(game_data)

    # Uncomment the following line to exit the loop for testing
    # sys.exit()

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(data_list)
# Out:
# ---------------------------------------------------------------------------
# InvalidChunkLength                        Traceback (most recent call last)
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/urllib3/response.py:710, in HTTPResponse._error_catcher(self)
#     709 try:
# --> 710     yield
#     712 except SocketTimeout as e:
#     713     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     714     # there is yet no clean way to get at it from this context.
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/urllib3/response.py:1073, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1072 while True:
# -> 1073     self._update_chunk_length()
#    1074     if self.chunk_left == 0:
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/urllib3/response.py:1008, in HTTPResponse._update_chunk_length(self)
#    1007 self.close()
# -> 1008 raise InvalidChunkLength(self, line) from None
#
# InvalidChunkLength: InvalidChunkLength(got length b'', 0 bytes read)
#
# The above exception was the direct cause of the following exception:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     815 try:
# --> 816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/urllib3/response.py:933, in HTTPResponse.stream(self, amt, decode_content)
#     932 if self.chunked and self.supports_chunked_reads():
# --> 933     yield from self.read_chunked(amt, decode_content=decode_content)
#     934 else:
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/urllib3/response.py:1061, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1056     raise BodyNotHttplibCompatible(
#    1057         "Body should be http.client.HTTPResponse like. "
#    1058         "It should have have an fp attribute which returns raw chunks."
#    1059     )
# -> 1061 with self._error_catcher():
#    1062     # Don't bother reading the body of a HEAD request.
#    1063     if self._original_response and is_response_to_head(self._original_response):
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/urllib3/response.py:727, in HTTPResponse._error_catcher(self)
#     725 except (HTTPException, OSError) as e:
#     726     # This includes IncompleteRead.
# --> 727     raise ProtocolError(f"Connection broken: {e!r}", e) from e
#     729 # If no exception is thrown, we should avoid cleaning up
#     730 # unnecessarily.
#
# ProtocolError: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[21], line 25
#      21 for url in sublisturls:
#      22     # Initialize a dictionary to store the data for each game
#      23     game_data = {}
# ---> 25     page = requests.get(url, headers=headers)
#      26     soup = BeautifulSoup(page.content, "html.parser")
#      28     # Extract objectid from the URL
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/virtualenv/juanpy/lib/python3.11/site-packages/requests/models.py:818, in Response.iter_content.<locals>.generate()
#     816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
# --> 818     raise ChunkedEncodingError(e)
#     819 except DecodeError as e:
#     820     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))

# %%
data_list
# Out:
# [{'Title': 'Brass: Birmingham ',
#   'Link': 'https://boardgamegeek.com/boardgame/224517/brass-birmingham',
#   'Rank': 1,
#   'Year': '2018',
#   'UsersRated': '46043',
#   'AveRating': '8.59731',
#   'Baverage': '8.41456',
#   'StdDev': '1.41606',
#   'AveWeight': '3.8789',
#   'NumWeights': '2229',
#   'NumPlays': '124812',
#   'NumAwards': 20,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 4,
#   'PCount_votes': '1106',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Hand Management\nIncome\nLoans\nMarket\nNetwork and Route Building\nTags\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '1',
#   'ScoreCat_1': '8.43113',
#   'AmazonPrice': '$63.48'},
#  {'Title': 'Pandemic Legacy: Season 1 ',
#   'Link': 'https://boardgamegeek.com/boardgame/161936/pandemic-legacy-season-1',
#   'Rank': 2,
#   'Year': '2015',
#   'UsersRated': '53558',
#   'AveRating': '8.52713',
#   'Baverage': '8.37875',
#   'StdDev': '1.5984',
#   'AveWeight': '2.8316',
#   'NumWeights': '1461',
#   'NumPlays': '287053',
#   'NumAwards': 30,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '863',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '60',
#   'Mechanics': 'Action Points\nCooperative Game\nHand Management\nLegacy Game\nPoint to Point Movement\nScenario / Mission / Campaign Game\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '1',
#   'ScoreCat_1': '8.37923',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '2',
#   'ScoreCat_2': '8.3668',
#   'AmazonPrice': '$71.97'},
#  {'Title': 'Gloomhaven ',
#   'Link': 'https://boardgamegeek.com/boardgame/174430/gloomhaven',
#   'Rank': 3,
#   'Year': '2017',
#   'UsersRated': '62246',
#   'AveRating': '8.58836',
#   'Baverage': '8.35218',
#   'StdDev': '1.73928',
#   'AveWeight': '3.9115',
#   'NumWeights': '2566',
#   'NumPlays': '513581',
#   'NumAwards': 30,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '1542',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Action Queue\nAction Retrieval\nCampaign / Battle Card Driven\nCard Play Conflict Resolution\nCommunication Limits\nCooperative Game\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '2',
#   'ScoreCat_1': '8.33121',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '4',
#   'ScoreCat_2': '8.31405',
#   'AmazonPrice': '$285.49'},
#  {'Title': 'Ark Nova ',
#   'Link': 'https://boardgamegeek.com/boardgame/342942/ark-nova',
#   'Rank': 4,
#   'Year': '2021',
#   'UsersRated': '43695',
#   'AveRating': '8.53514',
#   'Baverage': '8.33503',
#   'StdDev': '1.38399',
#   'AveWeight': '3.7606',
#   'NumWeights': '2297',
#   'NumPlays': '342465',
#   'NumAwards': 36,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 3,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '1762',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '150',
#   'Mechanics': 'Action Queue\nEnd Game Bonuses\nGrid Coverage\nHand Management\nHexagon Grid\nIncome\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '3',
#   'ScoreCat_1': '8.3448',
#   'AmazonPrice': '$56.92'},
#  {'Title': 'Twilight Imperium: Fourth Edition ',
#   'Link': 'https://boardgamegeek.com/boardgame/233078/twilight-imperium-fourth-edition',
#   'Rank': 5,
#   'Year': '2017',
#   'UsersRated': '23849',
#   'AveRating': '8.60087',
#   'Baverage': '8.24171',
#   'StdDev': '1.62048',
#   'AveWeight': '4.319',
#   'NumWeights': '1166',
#   'NumPlays': '41631',
#   'NumAwards': 2,
#   'PCountRecomm_min': 3,
#   'PCountRecomm_max': 6,
#   'PCountBest_min': 6,
#   'PCountBest_max': 6,
#   'PCount_votes': '572',
#   'MinPlayTime': '240',
#   'MaxPlayTime': '480',
#   'Mechanics': 'Action Drafting\nArea-Impulse\nDice Rolling\nFollow\nGrid Movement\nHexagon Grid\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '3',
#   'ScoreCat_1': '8.26231',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '5',
#   'ScoreCat_2': '8.26381',
#   'AmazonPrice': '$131.99'},
#  {'Title': 'Dune: Imperium ',
#   'Link': 'https://boardgamegeek.com/boardgame/316554/dune-imperium',
#   'Rank': 6,
#   'Year': '2020',
#   'UsersRated': '45614',
#   'AveRating': '8.43546',
#   'Baverage': '8.23065',
#   'StdDev': '1.27194',
#   'AveWeight': '3.0483',
#   'NumWeights': '1616',
#   'NumPlays': '166602',
#   'NumAwards': 27,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 4,
#   'PCount_votes': '1310',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Card Play Conflict Resolution\nDeck, Bag, and Pool Building\nDelayed Purchase\nForce Commitment\nIncrease Value of Unchosen Resources\nMulti-Use Cards\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '6',
#   'ScoreCat_1': '8.23235',
#   'AmazonPrice': '$51.35'},
#  {'Title': 'Terraforming Mars ',
#   'Link': 'https://boardgamegeek.com/boardgame/167791/terraforming-mars',
#   'Rank': 7,
#   'Year': '2016',
#   'UsersRated': '99208',
#   'AveRating': '8.35948',
#   'Baverage': '8.21267',
#   'StdDev': '1.42039',
#   'AveWeight': '3.2612',
#   'NumWeights': '4115',
#   'NumPlays': '631720',
#   'NumAwards': 40,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '2559',
#   'MinPlayTime': '120',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Closed Drafting\nContracts\nEnclosure\nEnd Game Bonuses\nHand Management\nHexagon Grid\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '7',
#   'ScoreCat_1': '8.19006',
#   'AmazonPrice': '$57.85'},
#  {'Title': 'War of the Ring: Second Edition ',
#   'Link': 'https://boardgamegeek.com/boardgame/115746/war-of-the-ring-second-edition',
#   'Rank': 8,
#   'Year': '2011',
#   'UsersRated': '21397',
#   'AveRating': '8.54215',
#   'Baverage': '8.18653',
#   'StdDev': '1.47406',
#   'AveWeight': '4.2147',
#   'NumWeights': '1183',
#   'NumPlays': '36087',
#   'NumAwards': 0,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 2,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '507',
#   'MinPlayTime': '150',
#   'MaxPlayTime': '180',
#   'Mechanics': 'Action Drafting\nArea Majority / Influence\nArea Movement\nCampaign / Battle Card Driven\nCard Play Conflict Resolution\nDice Rolling\n',
#   'Category_1': 'War ',
#   'RankCat_1': '1',
#   'ScoreCat_1': '8.28563',
#   'Category_2': 'Thematic',
#   'RankCat_2': '4',
#   'ScoreCat_2': '8.24584',
#   'AmazonPrice': '$71.68'},
#  {'Title': 'Star Wars: Rebellion ',
#   'Link': 'https://boardgamegeek.com/boardgame/187645/star-wars-rebellion',
#   'Rank': 9,
#   'Year': '2016',
#   'UsersRated': '32502',
#   'AveRating': '8.41979',
#   'Baverage': '8.17126',
#   'StdDev': '1.36406',
#   'AveWeight': '3.7454',
#   'NumWeights': '1135',
#   'NumPlays': '50309',
#   'NumAwards': 17,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 2,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '661',
#   'MinPlayTime': '180',
#   'MaxPlayTime': '240',
#   'Mechanics': 'Area Majority / Influence\nArea Movement\nArea-Impulse\nCard Play Conflict Resolution\nContracts\nDelayed Purchase\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '5',
#   'ScoreCat_1': '8.20703',
#   'AmazonPrice': '$87.99'},
#  {'Title': 'Gloomhaven: Jaws of the Lion ',
#   'Link': 'https://boardgamegeek.com/boardgame/291457/gloomhaven-jaws-of-the-lion',
#   'Rank': 10,
#   'Year': '2020',
#   'UsersRated': '34361',
#   'AveRating': '8.43896',
#   'Baverage': '8.16457',
#   'StdDev': '1.46561',
#   'AveWeight': '3.6408',
#   'NumWeights': '994',
#   'NumPlays': '170363',
#   'NumAwards': 20,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '733',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Action Queue\nAction Retrieval\nCampaign / Battle Card Driven\nCommunication Limits\nCooperative Game\nCritical Hits and Failures\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '7',
#   'ScoreCat_1': '8.17441',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '9',
#   'ScoreCat_2': '8.14174',
#   'AmazonPrice': '$39.97'},
#  {'Title': 'Spirit Island ',
#   'Link': 'https://boardgamegeek.com/boardgame/162886/spirit-island',
#   'Rank': 11,
#   'Year': '2017',
#   'UsersRated': '51633',
#   'AveRating': '8.3439',
#   'Baverage': '8.14453',
#   'StdDev': '1.50942',
#   'AveWeight': '4.0662',
#   'NumWeights': '2839',
#   'NumPlays': '314822',
#   'NumAwards': 16,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '1781',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Action Retrieval\nArea Majority / Influence\nAutomatic Resource Growth\nCampaign / Battle Card Driven\nCooperative Game\nHand Management\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '10',
#   'ScoreCat_1': '8.12494',
#   'AmazonPrice': '$72.19'},
#  {'Title': 'Gaia Project ',
#   'Link': 'https://boardgamegeek.com/boardgame/220308/gaia-project',
#   'Rank': 12,
#   'Year': '2017',
#   'UsersRated': '27177',
#   'AveRating': '8.37616',
#   'Baverage': '8.11274',
#   'StdDev': '1.40976',
#   'AveWeight': '4.393',
#   'NumWeights': '1687',
#   'NumPlays': '107202',
#   'NumAwards': 14,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 4,
#   'PCount_votes': '712',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '150',
#   'Mechanics': 'End Game Bonuses\nHexagon Grid\nIncome\nModular Board\nNetwork and Route Building\nSolo / Solitaire Game\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '8',
#   'ScoreCat_1': '8.15371',
#   'AmazonPrice': '$99.95'},
#  {'Title': 'Twilight Struggle ',
#   'Link': 'https://boardgamegeek.com/boardgame/12333/twilight-struggle',
#   'Rank': 13,
#   'Year': '2005',
#   'UsersRated': '48837',
#   'AveRating': '8.24659',
#   'Baverage': '8.06799',
#   'StdDev': '1.57576',
#   'AveWeight': '3.607',
#   'NumWeights': '3944',
#   'NumPlays': '126817',
#   'NumAwards': 13,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 2,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '887',
#   'MinPlayTime': '120',
#   'MaxPlayTime': '180',
#   'Mechanics': 'Action/Event\nAdvantage Token\nArea Majority / Influence\nCampaign / Battle Card Driven\nDice Rolling\nEvents\n',
#   'Category_1': 'War ',
#   'RankCat_1': '2',
#   'ScoreCat_1': '8.1852',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '12',
#   'ScoreCat_2': '8.05437',
#   'AmazonPrice': '$54.59'},
#  {'Title': 'Through the Ages: A New Story of Civilization ',
#   'Link': 'https://boardgamegeek.com/boardgame/182028/through-the-ages-a-new-story-of-civilization',
#   'Rank': 14,
#   'Year': '2015',
#   'UsersRated': '31679',
#   'AveRating': '8.28895',
#   'Baverage': '8.05912',
#   'StdDev': '1.51832',
#   'AveWeight': '4.4379',
#   'NumWeights': '1571',
#   'NumPlays': '132018',
#   'NumAwards': 3,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '719',
#   'MinPlayTime': '120',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Action Points\nAuction: Dutch\nAuction/Bidding\nEvents\nIncome\nOpen Drafting\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '11',
#   'ScoreCat_1': '8.09008',
#   'AmazonPrice': '$78.88'},
#  {'Title': 'Great Western Trail ',
#   'Link': 'https://boardgamegeek.com/boardgame/193738/great-western-trail',
#   'Rank': 15,
#   'Year': '2016',
#   'UsersRated': '40886',
#   'AveRating': '8.19383',
#   'Baverage': '8.02627',
#   'StdDev': '1.31011',
#   'AveWeight': '3.6995',
#   'NumWeights': '1594',
#   'NumPlays': '143041',
#   'NumAwards': 31,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '868',
#   'MinPlayTime': '75',
#   'MaxPlayTime': '150',
#   'Mechanics': 'Deck, Bag, and Pool Building\nHand Management\nOwnership\nSet Collection\nTrack Movement\nVariable Set-up\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '15',
#   'ScoreCat_1': '8.04663',
#   'AmazonPrice': '$49.99'},
#  {'Title': 'The Castles of Burgundy ',
#   'Link': 'https://boardgamegeek.com/boardgame/84876/the-castles-of-burgundy',
#   'Rank': 16,
#   'Year': '2011',
#   'UsersRated': '62345',
#   'AveRating': '8.14151',
#   'Baverage': '8.01654',
#   'StdDev': '1.24452',
#   'AveWeight': '2.9789',
#   'NumWeights': '2935',
#   'NumPlays': '351208',
#   'NumAwards': 14,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '1522',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Dice Rolling\nEnd Game Bonuses\nGrid Coverage\nHexagon Grid\nOpen Drafting\nPattern Building\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '16',
#   'ScoreCat_1': '8.01614',
#   'AmazonPrice': '$49.56'},
#  {'Title': 'Scythe ',
#   'Link': 'https://boardgamegeek.com/boardgame/169786/scythe',
#   'Rank': 17,
#   'Year': '2016',
#   'UsersRated': '83587',
#   'AveRating': '8.14395',
#   'Baverage': '7.99193',
#   'StdDev': '1.44907',
#   'AveWeight': '3.4452',
#   'NumWeights': '3277',
#   'NumPlays': '298286',
#   'NumAwards': 33,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '1503',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '115',
#   'Mechanics': 'Area Majority / Influence\nCard Play Conflict Resolution\nContracts\nEnd Game Bonuses\nForce Commitment\nGrid Movement\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '21',
#   'ScoreCat_1': '7.96208',
#   'AmazonPrice': '$80.99'},
#  {'Title': 'Eclipse: Second Dawn for the Galaxy ',
#   'Link': 'https://boardgamegeek.com/boardgame/246900/eclipse-second-dawn-for-the-galaxy',
#   'Rank': 18,
#   'Year': '2020',
#   'UsersRated': '13629',
#   'AveRating': '8.45874',
#   'Baverage': '7.97697',
#   'StdDev': '1.36967',
#   'AveWeight': '3.6463',
#   'NumWeights': '475',
#   'NumPlays': '25981',
#   'NumAwards': 4,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 6,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '312',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '200',
#   'Mechanics': 'Alliances\nArea Majority / Influence\nArea-Impulse\nDice Rolling\nGrid Movement\nHexagon Grid\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '13',
#   'ScoreCat_1': '8.05377',
#   'AmazonPrice': '$184.75'},
#  {'Title': '7 Wonders Duel ',
#   'Link': 'https://boardgamegeek.com/boardgame/173346/7-wonders-duel',
#   'Rank': 19,
#   'Year': '2015',
#   'UsersRated': '94764',
#   'AveRating': '8.0955',
#   'Baverage': '7.97176',
#   'StdDev': '1.19422',
#   'AveWeight': '2.2293',
#   'NumWeights': '3000',
#   'NumPlays': '515446',
#   'NumAwards': 24,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 2,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '1329',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '30',
#   'Mechanics': 'End Game Bonuses\nIncome\nLayering\nMarket\nModular Board\nMulti-Use Cards\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '22',
#   'ScoreCat_1': '7.93422',
#   'AmazonPrice': '$21.99'},
#  {'Title': 'Brass: Lancashire ',
#   'Link': 'https://boardgamegeek.com/boardgame/28720/brass-lancashire',
#   'Rank': 20,
#   'Year': '2007',
#   'UsersRated': '24950',
#   'AveRating': '8.19355',
#   'Baverage': '7.96197',
#   'StdDev': '1.36642',
#   'AveWeight': '3.8565',
#   'NumWeights': '1665',
#   'NumPlays': '75288',
#   'NumAwards': 7,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '620',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Hand Management\nIncome\nLoans\nMarket\nNetwork and Route Building\nTech Trees / Tech Tracks\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '17',
#   'ScoreCat_1': '8.0106',
#   'AmazonPrice': '$64.99'},
#  {'Title': 'Nemesis ',
#   'Link': 'https://boardgamegeek.com/boardgame/167355/nemesis',
#   'Rank': 21,
#   'Year': '2018',
#   'UsersRated': '30598',
#   'AveRating': '8.27056',
#   'Baverage': '7.9548',
#   'StdDev': '1.51473',
#   'AveWeight': '3.4633',
#   'NumWeights': '1118',
#   'NumPlays': '70448',
#   'NumAwards': 11,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 5,
#   'PCount_votes': '723',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '180',
#   'Mechanics': 'Campaign / Battle Card Driven\nCooperative Game\nDice Rolling\nHand Management\nHidden Roles\nInterrupts\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '12',
#   'ScoreCat_1': '7.96081',
#   'AmazonPrice': '$118.33'},
#  {'Title': 'Clank! Legacy: Acquisitions Incorporated ',
#   'Link': 'https://boardgamegeek.com/boardgame/266507/clank-legacy-acquisitions-incorporated',
#   'Rank': 22,
#   'Year': '2019',
#   'UsersRated': '9453',
#   'AveRating': '8.53578',
#   'Baverage': '7.94607',
#   'StdDev': '1.42479',
#   'AveWeight': '2.7273',
#   'NumWeights': '143',
#   'NumPlays': '55058',
#   'NumAwards': 3,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '130',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Deck, Bag, and Pool Building\nDelayed Purchase\nEnd Game Bonuses\nEvents\nLegacy Game\nMap Addition\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '8',
#   'ScoreCat_1': '8.13181',
#   'AmazonPrice': '$95.00'},
#  {'Title': 'A Feast for Odin ',
#   'Link': 'https://boardgamegeek.com/boardgame/177736/feast-odin',
#   'Rank': 23,
#   'Year': '2016',
#   'UsersRated': '28577',
#   'AveRating': '8.17203',
#   'Baverage': '7.94378',
#   'StdDev': '1.37069',
#   'AveWeight': '3.8617',
#   'NumWeights': '1034',
#   'NumPlays': '105872',
#   'NumAwards': 9,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '585',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Automatic Resource Growth\nDice Rolling\nGrid Coverage\nIncome\nPush Your Luck\nSolo / Solitaire Game\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '19',
#   'ScoreCat_1': '7.9743',
#   'AmazonPrice': '$92.00'},
#  {'Title': 'Concordia ',
#   'Link': 'https://boardgamegeek.com/boardgame/124361/concordia',
#   'Rank': 24,
#   'Year': '2013',
#   'UsersRated': '40530',
#   'AveRating': '8.0941',
#   'Baverage': '7.94239',
#   'StdDev': '1.19649',
#   'AveWeight': '2.9894',
#   'NumWeights': '1609',
#   'NumPlays': '132828',
#   'NumAwards': 11,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '685',
#   'MinPlayTime': '100',
#   'MaxPlayTime': '100',
#   'Mechanics': 'Action Retrieval\nAdvantage Token\nAuction: Dutch\nDeck, Bag, and Pool Building\nEnd Game Bonuses\nHand Management\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '20',
#   'ScoreCat_1': '7.96264',
#   'AmazonPrice': '$52.21'},
#  {'Title': 'Wingspan ',
#   'Link': 'https://boardgamegeek.com/boardgame/266192/wingspan',
#   'Rank': 25,
#   'Year': '2019',
#   'UsersRated': '93358',
#   'AveRating': '8.04726',
#   'Baverage': '7.89824',
#   'StdDev': '1.36087',
#   'AveWeight': '2.4652',
#   'NumWeights': '3085',
#   'NumPlays': '646633',
#   'NumAwards': 43,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '1837',
#   'MinPlayTime': '40',
#   'MaxPlayTime': '70',
#   'Mechanics': 'Action Queue\nDice Rolling\nEnd Game Bonuses\nHand Management\nOnce-Per-Game Abilities\nOpen Drafting\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '36',
#   'ScoreCat_1': '7.83325',
#   'Category_2': 'Family ',
#   'RankCat_2': '2',
#   'ScoreCat_2': '7.91301',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Arkham Horror: The Card Game ',
#   'Link': 'https://boardgamegeek.com/boardgame/205637/arkham-horror-the-card-game',
#   'Rank': 26,
#   'Year': '2016',
#   'UsersRated': '43159',
#   'AveRating': '8.1308',
#   'Baverage': '7.90128',
#   'StdDev': '1.54472',
#   'AveWeight': '3.5394',
#   'NumWeights': '1435',
#   'NumPlays': '306993',
#   'NumAwards': 15,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 2,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '1006',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Action Points\nArea Movement\nCommunication Limits\nCooperative Game\nDeck Construction\nEvents\n',
#   'Category_1': 'Customizable',
#   'RankCat_1': '1',
#   'ScoreCat_1': '8.07265',
#   'Category_2': 'Thematic',
#   'RankCat_2': '13',
#   'ScoreCat_2': '7.92042',
#   'AmazonPrice': '$19.00'},
#  {'Title': 'Terra Mystica ',
#   'Link': 'https://boardgamegeek.com/boardgame/120677/terra-mystica',
#   'Rank': 27,
#   'Year': '2012',
#   'UsersRated': '48030',
#   'AveRating': '8.06163',
#   'Baverage': '7.89646',
#   'StdDev': '1.47355',
#   'AveWeight': '3.9734',
#   'NumWeights': '2932',
#   'NumPlays': '161356',
#   'NumAwards': 29,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '1038',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '150',
#   'Mechanics': 'Area Majority / Influence\nChaining\nEnd Game Bonuses\nHexagon Grid\nIncome\nIncrease Value of Unchosen Resources\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '26',
#   'ScoreCat_1': '7.90528',
#   'AmazonPrice': '$58.97'},
#  {'Title': 'Lost Ruins of Arnak ',
#   'Link': 'https://boardgamegeek.com/boardgame/312484/lost-ruins-of-arnak',
#   'Rank': 28,
#   'Year': '2020',
#   'UsersRated': '44219',
#   'AveRating': '8.07435',
#   'Baverage': '7.89673',
#   'StdDev': '1.23889',
#   'AveWeight': '2.9166',
#   'NumWeights': '1439',
#   'NumPlays': '221570',
#   'NumAwards': 40,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '869',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Contracts\nDeck, Bag, and Pool Building\nMarket\nMulti-Use Cards\nOnce-Per-Game Abilities\nResource to Move\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '28',
#   'ScoreCat_1': '7.89234',
#   'AmazonPrice': '$41.96'},
#  {'Title': 'Great Western Trail: Second Edition ',
#   'Link': 'https://boardgamegeek.com/boardgame/341169/great-western-trail-second-edition',
#   'Rank': 29,
#   'Year': '2021',
#   'UsersRated': '12709',
#   'AveRating': '8.34052',
#   'Baverage': '7.90239',
#   'StdDev': '1.28389',
#   'AveWeight': '3.7205',
#   'NumWeights': '390',
#   'NumPlays': '43976',
#   'NumAwards': 0,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '231',
#   'MinPlayTime': '75',
#   'MaxPlayTime': '150',
#   'Mechanics': 'Deck, Bag, and Pool Building\nHand Management\nOwnership\nSet Collection\nSolo / Solitaire Game\nTags\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '18',
#   'ScoreCat_1': '7.99191',
#   'AmazonPrice': '$54.93'},
#  {'Title': 'Root ',
#   'Link': 'https://boardgamegeek.com/boardgame/237182/root',
#   'Rank': 30,
#   'Year': '2018',
#   'UsersRated': '51437',
#   'AveRating': '8.07405',
#   'Baverage': '7.88603',
#   'StdDev': '1.46401',
#   'AveWeight': '3.8047',
#   'NumWeights': '2130',
#   'NumPlays': '178692',
#   'NumAwards': 35,
#   'PCountRecomm_min': 3,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '1136',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Action Points\nAction Queue\nAction Retrieval\nArea Majority / Influence\nArea Movement\nDice Rolling\n',
#   'Category_1': 'War ',
#   'RankCat_1': '11',
#   'ScoreCat_1': '7.75259',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '31',
#   'ScoreCat_2': '7.85666',
#   'AmazonPrice': '$51.00'},
#  {'Title': 'Frosthaven ',
#   'Link': 'https://boardgamegeek.com/boardgame/295770/frosthaven',
#   'Rank': 31,
#   'Year': '2022',
#   'UsersRated': '6996',
#   'AveRating': '8.83998',
#   'Baverage': '7.89267',
#   'StdDev': '2.00791',
#   'AveWeight': '4.3634',
#   'NumWeights': '366',
#   'NumPlays': '68769',
#   'NumAwards': 1,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '208',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '180',
#   'Mechanics': 'Campaign / Battle Card Driven\nCommunication Limits\nCooperative Game\nDeck Construction\nDeck, Bag, and Pool Building\nGrid Movement\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '6',
#   'ScoreCat_1': '8.20002',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '14',
#   'ScoreCat_2': '8.05',
#   'AmazonPrice': '$197.17'},
#  {'Title': 'Orléans ',
#   'Link': 'https://boardgamegeek.com/boardgame/164928/orleans',
#   'Rank': 32,
#   'Year': '2014',
#   'UsersRated': '31403',
#   'AveRating': '8.06113',
#   'Baverage': '7.87294',
#   'StdDev': '1.16466',
#   'AveWeight': '3.0291',
#   'NumWeights': '1064',
#   'NumPlays': '98628',
#   'NumAwards': 18,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '435',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Contracts\nDeck, Bag, and Pool Building\nEnd Game Bonuses\nEvents\nPoint to Point Movement\nSimultaneous Action Selection\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '27',
#   'ScoreCat_1': '7.90142',
#   'AmazonPrice': '$55.00'},
#  {'Title': 'Too Many Bones ',
#   'Link': 'https://boardgamegeek.com/boardgame/192135/too-many-bones',
#   'Rank': 33,
#   'Year': '2017',
#   'UsersRated': '13387',
#   'AveRating': '8.34232',
#   'Baverage': '7.86411',
#   'StdDev': '1.54233',
#   'AveWeight': '3.8518',
#   'NumWeights': '506',
#   'NumPlays': '65458',
#   'NumAwards': 4,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '369',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Cooperative Game\nDice Rolling\nDie Icon Resolution\nGrid Movement\nNarrative Choice / Paragraph\nResource to Move\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '11',
#   'ScoreCat_1': '7.98662',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '23',
#   'ScoreCat_2': '7.92177',
#   'AmazonPrice': '$150.00'},
#  {'Title': 'Mage Knight Board Game ',
#   'Link': 'https://boardgamegeek.com/boardgame/96848/mage-knight-board-game',
#   'Rank': 34,
#   'Year': '2011',
#   'UsersRated': '33335',
#   'AveRating': '8.08471',
#   'Baverage': '7.85327',
#   'StdDev': '1.635',
#   'AveWeight': '4.3629',
#   'NumWeights': '2709',
#   'NumPlays': '76611',
#   'NumAwards': 12,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 3,
#   'PCountBest_min': 1,
#   'PCountBest_max': 2,
#   'PCount_votes': '1292',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '240',
#   'Mechanics': 'Card Play Conflict Resolution\nCooperative Game\nDeck, Bag, and Pool Building\nDice Rolling\nGrid Movement\nHand Management\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '15',
#   'ScoreCat_1': '7.84771',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '32',
#   'ScoreCat_2': '7.85129',
#   'AmazonPrice': '$65.68'},
#  {'Title': 'The Crew: Mission Deep Sea ',
#   'Link': 'https://boardgamegeek.com/boardgame/324856/the-crew-mission-deep-sea',
#   'Rank': 35,
#   'Year': '2021',
#   'UsersRated': '17615',
#   'AveRating': '8.15107',
#   'Baverage': '7.8438',
#   'StdDev': '1.29039',
#   'AveWeight': '2.03',
#   'NumWeights': '333',
#   'NumPlays': '211753',
#   'NumAwards': 8,
#   'PCountRecomm_min': 3,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '248',
#   'MinPlayTime': '20',
#   'MaxPlayTime': '20',
#   'Mechanics': 'Communication Limits\nCooperative Game\nHand Management\nScenario / Mission / Campaign Game\nTrick-taking\n',
#   'Category_1': 'Family ',
#   'RankCat_1': '1',
#   'ScoreCat_1': '7.91861',
#   'AmazonPrice': '$14.95'},
#  {'Title': 'Everdell ',
#   'Link': 'https://boardgamegeek.com/boardgame/199792/everdell',
#   'Rank': 36,
#   'Year': '2018',
#   'UsersRated': '54791',
#   'AveRating': '8.02575',
#   'Baverage': '7.84667',
#   'StdDev': '1.29655',
#   'AveWeight': '2.8297',
#   'NumWeights': '1632',
#   'NumPlays': '215941',
#   'NumAwards': 22,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '927',
#   'MinPlayTime': '40',
#   'MaxPlayTime': '80',
#   'Mechanics': 'Contracts\nEnd Game Bonuses\nHand Management\nIncome\nOpen Drafting\nOwnership\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '41',
#   'ScoreCat_1': '7.80903',
#   'Category_2': 'Family ',
#   'RankCat_2': '3',
#   'ScoreCat_2': '7.85542',
#   'AmazonPrice': '$60.00'},
#  {'Title': 'Barrage ',
#   'Link': 'https://boardgamegeek.com/boardgame/251247/barrage',
#   'Rank': 37,
#   'Year': '2019',
#   'UsersRated': '17746',
#   'AveRating': '8.16322',
#   'Baverage': '7.84679',
#   'StdDev': '1.42861',
#   'AveWeight': '4.1201',
#   'NumWeights': '1016',
#   'NumPlays': '57614',
#   'NumAwards': 25,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '469',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Action Retrieval\nContracts\nEnd Game Bonuses\nIncome\nNetwork and Route Building\nOwnership\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '24',
#   'ScoreCat_1': '7.91073',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Viticulture Essential Edition ',
#   'Link': 'https://boardgamegeek.com/boardgame/183394/viticulture-essential-edition',
#   'Rank': 38,
#   'Year': '2015',
#   'UsersRated': '48761',
#   'AveRating': '7.98833',
#   'Baverage': '7.83843',
#   'StdDev': '1.27277',
#   'AveWeight': '2.8911',
#   'NumWeights': '1433',
#   'NumPlays': '170812',
#   'NumAwards': 1,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 3,
#   'PCountBest_max': 4,
#   'PCount_votes': '816',
#   'MinPlayTime': '45',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Contracts\nHand Management\nRace\nSolo / Solitaire Game\nTurn Order: Auction\nVictory Points as a Resource\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '37',
#   'ScoreCat_1': '7.83008',
#   'AmazonPrice': '$65.00'},
#  {'Title': 'Food Chain Magnate ',
#   'Link': 'https://boardgamegeek.com/boardgame/175914/food-chain-magnate',
#   'Rank': 39,
#   'Year': '2015',
#   'UsersRated': '20469',
#   'AveRating': '8.06098',
#   'Baverage': '7.8011',
#   'StdDev': '1.60427',
#   'AveWeight': '4.197',
#   'NumWeights': '990',
#   'NumPlays': '51339',
#   'NumAwards': 12,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 3,
#   'PCountBest_max': 4,
#   'PCount_votes': '353',
#   'MinPlayTime': '120',
#   'MaxPlayTime': '240',
#   'Mechanics': 'Delayed Purchase\nIncome\nMarket\nModular Board\nOpen Drafting\nSimultaneous Action Selection\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '33',
#   'ScoreCat_1': '7.85053',
#   'AmazonPrice': '$104.95'},
#  {'Title': 'Marvel Champions: The Card Game ',
#   'Link': 'https://boardgamegeek.com/boardgame/285774/marvel-champions-the-card-game',
#   'Rank': 40,
#   'Year': '2019',
#   'UsersRated': '23668',
#   'AveRating': '8.12231',
#   'Baverage': '7.79805',
#   'StdDev': '1.45878',
#   'AveWeight': '2.9314',
#   'NumWeights': '743',
#   'NumPlays': '483114',
#   'NumAwards': 12,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 3,
#   'PCountBest_min': 1,
#   'PCountBest_max': 2,
#   'PCount_votes': '774',
#   'MinPlayTime': '45',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Card Play Conflict Resolution\nCooperative Game\nDeck Construction\nHand Management\nInterrupts\nScenario / Mission / Campaign Game\n',
#   'Category_1': 'Customizable',
#   'RankCat_1': '3',
#   'ScoreCat_1': '7.91561',
#   'AmazonPrice': '$41.99'},
#  {'Title': 'Pax Pamir: Second Edition ',
#   'Link': 'https://boardgamegeek.com/boardgame/256960/pax-pamir-second-edition',
#   'Rank': 41,
#   'Year': '2019',
#   'UsersRated': '14106',
#   'AveRating': '8.19261',
#   'Baverage': '7.79545',
#   'StdDev': '1.5088',
#   'AveWeight': '3.859',
#   'NumWeights': '688',
#   'NumPlays': '53590',
#   'NumAwards': 16,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '498',
#   'MinPlayTime': '45',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Action Points\nArea Majority / Influence\nArea Movement\nAuction: Dutch\nHand Management\nIncrease Value of Unchosen Resources\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '30',
#   'ScoreCat_1': '7.8619',
#   'AmazonPrice': '$61.91'},
#  {'Title': 'Heat: Pedal to the Metal ',
#   'Link': 'https://boardgamegeek.com/boardgame/366013/heat-pedal-to-the-metal',
#   'Rank': 42,
#   'Year': '2022',
#   'UsersRated': '22984',
#   'AveRating': '8.07355',
#   'Baverage': '7.79997',
#   'StdDev': '1.31027',
#   'AveWeight': '2.196',
#   'NumWeights': '658',
#   'NumPlays': '124311',
#   'NumAwards': 23,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 6,
#   'PCountBest_min': 5,
#   'PCountBest_max': 6,
#   'PCount_votes': '571',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '60',
#   'Mechanics': 'Catch the Leader\nDeck, Bag, and Pool Building\nHand Management\nProgrammed Movement\nPush Your Luck\nRace\n',
#   'Category_1': 'Family ',
#   'RankCat_1': '4',
#   'ScoreCat_1': '7.83387',
#   'AmazonPrice': '$74.99'},
#  {'Title': 'Underwater Cities ',
#   'Link': 'https://boardgamegeek.com/boardgame/247763/underwater-cities',
#   'Rank': 43,
#   'Year': '2018',
#   'UsersRated': '19654',
#   'AveRating': '8.06224',
#   'Baverage': '7.78527',
#   'StdDev': '1.19649',
#   'AveWeight': '3.5946',
#   'NumWeights': '703',
#   'NumPlays': '74018',
#   'NumAwards': 15,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 3,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '577',
#   'MinPlayTime': '80',
#   'MaxPlayTime': '150',
#   'Mechanics': 'End Game Bonuses\nHand Management\nIncome\nNetwork and Route Building\nSolo / Solitaire Game\nTurn Order: Claim Action\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '34',
#   'ScoreCat_1': '7.84232',
#   'AmazonPrice': '$51.58'},
#  {'Title': 'Puerto Rico ',
#   'Link': 'https://boardgamegeek.com/boardgame/3076/puerto-rico',
#   'Rank': 44,
#   'Year': '2002',
#   'UsersRated': '71002',
#   'AveRating': '7.91777',
#   'Baverage': '7.77755',
#   'StdDev': '1.39131',
#   'AveWeight': '3.2692',
#   'NumWeights': '6233',
#   'NumPlays': '195153',
#   'NumAwards': 19,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '1571',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '150',
#   'Mechanics': 'Action Drafting\nEnd Game Bonuses\nFollow\nHidden Victory Points\nIncrease Value of Unchosen Resources\nTurn Order: Progressive\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '45',
#   'ScoreCat_1': '7.76506',
#   'AmazonPrice': '$92.98'},
#  {'Title': 'Cascadia ',
#   'Link': 'https://boardgamegeek.com/boardgame/295947/cascadia',
#   'Rank': 45,
#   'Year': '2021',
#   'UsersRated': '38800',
#   'AveRating': '7.95326',
#   'Baverage': '7.77202',
#   'StdDev': '1.11942',
#   'AveWeight': '1.8456',
#   'NumWeights': '1127',
#   'NumPlays': '237554',
#   'NumAwards': 35,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 2,
#   'PCountBest_max': 3,
#   'PCount_votes': '713',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '45',
#   'Mechanics': 'End Game Bonuses\nHexagon Grid\nOpen Drafting\nPattern Building\nSolo / Solitaire Game\nTile Placement\n',
#   'Category_1': 'Abstract ',
#   'RankCat_1': '1',
#   'ScoreCat_1': '7.74063',
#   'Category_2': 'Family ',
#   'RankCat_2': '6',
#   'ScoreCat_2': '7.80613',
#   'AmazonPrice': '$31.99'},
#  {'Title': 'Caverna: The Cave Farmers ',
#   'Link': 'https://boardgamegeek.com/boardgame/102794/caverna-the-cave-farmers',
#   'Rank': 46,
#   'Year': '2013',
#   'UsersRated': '34838',
#   'AveRating': '7.94668',
#   'Baverage': '7.76372',
#   'StdDev': '1.34054',
#   'AveWeight': '3.7797',
#   'NumWeights': '1657',
#   'NumPlays': '83611',
#   'NumAwards': 14,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '562',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '210',
#   'Mechanics': 'Automatic Resource Growth\nIncrease Value of Unchosen Resources\nSolo / Solitaire Game\nTile Placement\nTurn Order: Claim Action\nWorker Placement\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '42',
#   'ScoreCat_1': '7.77982',
#   'AmazonPrice': '$71.28'},
#  {'Title': 'Crokinole ',
#   'Link': 'https://boardgamegeek.com/boardgame/521/crokinole',
#   'Rank': 47,
#   'Year': '1876',
#   'UsersRated': '18052',
#   'AveRating': '8.03803',
#   'Baverage': '7.76772',
#   'StdDev': '1.60378',
#   'AveWeight': '1.23',
#   'NumWeights': '687',
#   'NumPlays': '210775',
#   'NumAwards': 0,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 2,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '262',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '30',
#   'Mechanics': 'Flicking\nTeam-Based Game\n',
#   'Category_1': 'Family ',
#   'RankCat_1': '5',
#   'ScoreCat_1': '7.82488',
#   'AmazonPrice': '$108.99'},
#  {'Title': 'Blood Rage ',
#   'Link': 'https://boardgamegeek.com/boardgame/170216/blood-rage',
#   'Rank': 48,
#   'Year': '2015',
#   'UsersRated': '47189',
#   'AveRating': '7.92797',
#   'Baverage': '7.7556',
#   'StdDev': '1.41607',
#   'AveWeight': '2.8791',
#   'NumWeights': '1539',
#   'NumPlays': '101577',
#   'NumAwards': 19,
#   'PCountRecomm_min': 3,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '979',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Action Points\nArea Majority / Influence\nArea Movement\nCard Play Conflict Resolution\nClosed Drafting\nHand Management\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '50',
#   'ScoreCat_1': '7.73848',
#   'AmazonPrice': '$89.99'},
#  {'Title': 'Anachrony ',
#   'Link': 'https://boardgamegeek.com/boardgame/185343/anachrony',
#   'Rank': 49,
#   'Year': '2017',
#   'UsersRated': '18660',
#   'AveRating': '8.07558',
#   'Baverage': '7.75756',
#   'StdDev': '1.38494',
#   'AveWeight': '4.0108',
#   'NumWeights': '1018',
#   'NumPlays': '47025',
#   'NumAwards': 9,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '363',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Contracts\nDice Rolling\nEnd Game Bonuses\nSolo / Solitaire Game\nTurn Order: Claim Action\nVariable Player Powers\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '40',
#   'ScoreCat_1': '7.80989',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Kanban EV ',
#   'Link': 'https://boardgamegeek.com/boardgame/284378/kanban-ev',
#   'Rank': 50,
#   'Year': '2020',
#   'UsersRated': '7689',
#   'AveRating': '8.42603',
#   'Baverage': '7.76572',
#   'StdDev': '1.29761',
#   'AveWeight': '4.3079',
#   'NumWeights': '445',
#   'NumPlays': '18918',
#   'NumAwards': 8,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '176',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '180',
#   'Mechanics': 'Action Points\nHand Management\nVariable Phase Order\nWorker Placement\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '25',
#   'ScoreCat_1': '7.90709',
#   'AmazonPrice': '$121.49'},
#  {'Title': 'On Mars ',
#   'Link': 'https://boardgamegeek.com/boardgame/184267/on-mars',
#   'Rank': 51,
#   'Year': '2020',
#   'UsersRated': '12627',
#   'AveRating': '8.18982',
#   'Baverage': '7.7507',
#   'StdDev': '1.51459',
#   'AveWeight': '4.6722',
#   'NumWeights': '1565',
#   'NumPlays': '32422',
#   'NumAwards': 16,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '382',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '150',
#   'Mechanics': 'Contracts\nDelayed Purchase\nEnd Game Bonuses\nHexagon Grid\nIncome\nMovement Points\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '35',
#   'ScoreCat_1': '7.83534',
#   'AmazonPrice': '$112.49'},
#  {'Title': 'Agricola ',
#   'Link': 'https://boardgamegeek.com/boardgame/31260/agricola',
#   'Rank': 52,
#   'Year': '2007',
#   'UsersRated': '72814',
#   'AveRating': '7.87506',
#   'Baverage': '7.74774',
#   'StdDev': '1.54841',
#   'AveWeight': '3.6364',
#   'NumWeights': '6334',
#   'NumPlays': '277316',
#   'NumAwards': 36,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 3,
#   'PCountBest_max': 4,
#   'PCount_votes': '1980',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '150',
#   'Mechanics': 'Automatic Resource Growth\nClosed Drafting\nEnclosure\nHand Management\nIncrease Value of Unchosen Resources\nSolo / Solitaire Game\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '51',
#   'ScoreCat_1': '7.73476',
#   'AmazonPrice': '$58.95'},
#  {'Title': 'Pandemic Legacy: Season 0 ',
#   'Link': 'https://boardgamegeek.com/boardgame/314040/pandemic-legacy-season-0',
#   'Rank': 53,
#   'Year': '2020',
#   'UsersRated': '7685',
#   'AveRating': '8.39745',
#   'Baverage': '7.74916',
#   'StdDev': '1.56196',
#   'AveWeight': '3.1533',
#   'NumWeights': '150',
#   'NumPlays': '56951',
#   'NumAwards': 5,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '125',
#   'MinPlayTime': '45',
#   'MaxPlayTime': '60',
#   'Mechanics': 'Action Points\nCooperative Game\nHand Management\nLegacy Game\nPoint to Point Movement\nScenario / Mission / Campaign Game\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '10',
#   'ScoreCat_1': '7.98916',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '29',
#   'ScoreCat_2': '7.87051',
#   'AmazonPrice': '$69.90'},
#  {'Title': 'Sleeping Gods ',
#   'Link': 'https://boardgamegeek.com/boardgame/255984/sleeping-gods',
#   'Rank': 54,
#   'Year': '2021',
#   'UsersRated': '12059',
#   'AveRating': '8.21189',
#   'Baverage': '7.7423',
#   'StdDev': '1.45421',
#   'AveWeight': '3.2439',
#   'NumWeights': '410',
#   'NumPlays': '38431',
#   'NumAwards': 24,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 3,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '346',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '1200',
#   'Mechanics': 'Action Points\nCooperative Game\nEvents\nHand Management\nNarrative Choice / Paragraph\nPush Your Luck\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '14',
#   'ScoreCat_1': '7.85419',
#   'AmazonPrice': '$84.99'},
#  {'Title': 'Pandemic Legacy: Season 2 ',
#   'Link': 'https://boardgamegeek.com/boardgame/221107/pandemic-legacy-season-2',
#   'Rank': 55,
#   'Year': '2017',
#   'UsersRated': '16903',
#   'AveRating': '8.03163',
#   'Baverage': '7.72095',
#   'StdDev': '1.68965',
#   'AveWeight': '3.2516',
#   'NumWeights': '318',
#   'NumPlays': '121359',
#   'NumAwards': 10,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '232',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '60',
#   'Mechanics': 'Action Points\nCooperative Game\nHand Management\nLegacy Game\nPick-up and Deliver\nPoint to Point Movement\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '19',
#   'ScoreCat_1': '7.8331',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '44',
#   'ScoreCat_2': '7.76963',
#   'AmazonPrice': '$53.99'},
#  {'Title': 'Lisboa ',
#   'Link': 'https://boardgamegeek.com/boardgame/161533/lisboa',
#   'Rank': 56,
#   'Year': '2017',
#   'UsersRated': '11135',
#   'AveRating': '8.18843',
#   'Baverage': '7.71913',
#   'StdDev': '1.45658',
#   'AveWeight': '4.5796',
#   'NumWeights': '1037',
#   'NumPlays': '27783',
#   'NumAwards': 21,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '291',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Area Majority / Influence\nHand Management\nOpen Drafting\nSolo / Solitaire Game\nTile Placement\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '38',
#   'ScoreCat_1': '7.81686',
#   'AmazonPrice': '$125.99'},
#  {'Title': 'Mansions of Madness: Second Edition ',
#   'Link': 'https://boardgamegeek.com/boardgame/205059/mansions-of-madness-second-edition',
#   'Rank': 57,
#   'Year': '2016',
#   'UsersRated': '36420',
#   'AveRating': '7.94735',
#   'Baverage': '7.71376',
#   'StdDev': '1.50175',
#   'AveWeight': '2.6872',
#   'NumWeights': '745',
#   'NumPlays': '92271',
#   'NumAwards': 9,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 3,
#   'PCountBest_max': 4,
#   'PCount_votes': '466',
#   'MinPlayTime': '120',
#   'MaxPlayTime': '180',
#   'Mechanics': 'Area Movement\nCooperative Game\nDice Rolling\nHand Management\nMap Addition\nModular Board\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '21',
#   'ScoreCat_1': '7.74682',
#   'AmazonPrice': '$87.99'},
#  {'Title': 'Maracaibo ',
#   'Link': 'https://boardgamegeek.com/boardgame/276025/maracaibo',
#   'Rank': 58,
#   'Year': '2019',
#   'UsersRated': '16339',
#   'AveRating': '8.01983',
#   'Baverage': '7.70062',
#   'StdDev': '1.28527',
#   'AveWeight': '3.9177',
#   'NumWeights': '802',
#   'NumPlays': '61252',
#   'NumAwards': 13,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '388',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Contracts\nEnd Game Bonuses\nEvents\nHand Management\nIncome\nMovement Points\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '46',
#   'ScoreCat_1': '7.76458',
#   'AmazonPrice': '$60.21'},
#  {'Title': 'Cthulhu: Death May Die ',
#   'Link': 'https://boardgamegeek.com/boardgame/253344/cthulhu-death-may-die',
#   'Rank': 59,
#   'Year': '2019',
#   'UsersRated': '12483',
#   'AveRating': '8.18245',
#   'Baverage': '7.71008',
#   'StdDev': '1.38347',
#   'AveWeight': '2.4698',
#   'NumWeights': '364',
#   'NumPlays': '48456',
#   'NumAwards': 7,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '292',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Action Points\nArea Movement\nCooperative Game\nDice Rolling\nRole Playing\nScenario / Mission / Campaign Game\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '17',
#   'ScoreCat_1': '7.83882',
#   'AmazonPrice': '$97.00'},
#  {'Title': "Tzolk'in: The Mayan Calendar ",
#   'Link': 'https://boardgamegeek.com/boardgame/126163/tzolkin-the-mayan-calendar',
#   'Rank': 60,
#   'Year': '2012',
#   'UsersRated': '39349',
#   'AveRating': '7.85912',
#   'Baverage': '7.70183',
#   'StdDev': '1.26347',
#   'AveWeight': '3.6668',
#   'NumWeights': '1975',
#   'NumPlays': '121053',
#   'NumAwards': 27,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '613',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Bias\nEnd Game Bonuses\nTurn Order: Claim Action\nWorker Placement\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '55',
#   'ScoreCat_1': '7.72063',
#   'AmazonPrice': '$59.95'},
#  {'Title': 'Power Grid ',
#   'Link': 'https://boardgamegeek.com/boardgame/2651/power-grid',
#   'Rank': 61,
#   'Year': '2004',
#   'UsersRated': '65491',
#   'AveRating': '7.81079',
#   'Baverage': '7.69945',
#   'StdDev': '1.33582',
#   'AveWeight': '3.2533',
#   'NumWeights': '4979',
#   'NumPlays': '154113',
#   'NumAwards': 20,
#   'PCountRecomm_min': 3,
#   'PCountRecomm_max': 6,
#   'PCountBest_min': 4,
#   'PCountBest_max': 5,
#   'PCount_votes': '1295',
#   'MinPlayTime': '120',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Auction: Turn Order Until Pass\nAuction/Bidding\nCatch the Leader\nIncome\nMarket\nNetwork and Route Building\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '59',
#   'ScoreCat_1': '7.69585',
#   'AmazonPrice': '$41.17'},
#  {'Title': 'Obsession ',
#   'Link': 'https://boardgamegeek.com/boardgame/231733/obsession',
#   'Rank': 62,
#   'Year': '2018',
#   'UsersRated': '12467',
#   'AveRating': '8.14745',
#   'Baverage': '7.70052',
#   'StdDev': '1.32354',
#   'AveWeight': '3.1082',
#   'NumWeights': '462',
#   'NumPlays': '61846',
#   'NumAwards': 1,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '342',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Action Retrieval\nDeck, Bag, and Pool Building\nHand Management\nOpen Drafting\nSolo / Solitaire Game\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '20',
#   'ScoreCat_1': '7.76658',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '43',
#   'ScoreCat_2': '7.77199',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Grand Austria Hotel ',
#   'Link': 'https://boardgamegeek.com/boardgame/182874/grand-austria-hotel',
#   'Rank': 63,
#   'Year': '2015',
#   'UsersRated': '20991',
#   'AveRating': '7.94638',
#   'Baverage': '7.69051',
#   'StdDev': '1.25015',
#   'AveWeight': '3.2144',
#   'NumWeights': '821',
#   'NumPlays': '99051',
#   'NumAwards': 6,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 3,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '729',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Action Drafting\nContracts\nDice Rolling\nEnd Game Bonuses\nHand Management\nSet Collection\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '52',
#   'ScoreCat_1': '7.73421',
#   'AmazonPrice': '$59.97'},
#  {'Title': 'The Quacks of Quedlinburg ',
#   'Link': 'https://boardgamegeek.com/boardgame/244521/the-quacks-of-quedlinburg',
#   'Rank': 64,
#   'Year': '2018',
#   'UsersRated': '49759',
#   'AveRating': '7.82294',
#   'Baverage': '7.68262',
#   'StdDev': '1.24039',
#   'AveWeight': '1.9461',
#   'NumWeights': '1205',
#   'NumPlays': '241816',
#   'NumAwards': 28,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '678',
#   'MinPlayTime': '45',
#   'MaxPlayTime': '45',
#   'Mechanics': 'Catch the Leader\nDeck, Bag, and Pool Building\nDelayed Purchase\nDice Rolling\nEvents\nOpen Drafting\n',
#   'Category_1': 'Family ',
#   'RankCat_1': '7',
#   'ScoreCat_1': '7.70936',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Clans of Caledonia ',
#   'Link': 'https://boardgamegeek.com/boardgame/216132/clans-caledonia',
#   'Rank': 65,
#   'Year': '2017',
#   'UsersRated': '20432',
# ...
#   'Category_1': 'Thematic',
#   'RankCat_1': '201',
#   'ScoreCat_1': '6.81828',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '585',
#   'ScoreCat_2': '6.71602',
#   'AmazonPrice': '$59.99'},
#  {'Title': 'Lanterns: The Harvest Festival ',
#   'Link': 'https://boardgamegeek.com/boardgame/160851/lanterns-harvest-festival',
#   'Rank': 979,
#   'Year': '2015',
#   'UsersRated': '11445',
#   'AveRating': '6.86544',
#   'Baverage': '6.61999',
#   'StdDev': '1.19009',
#   'AveWeight': '1.5496',
#   'NumWeights': '262',
#   'NumPlays': '40001',
#   'NumAwards': 4,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '106',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '30',
#   'Mechanics': 'Hand Management\nPattern Building\nSet Collection\nTile Placement\n',
#   'Category_1': 'Family ',
#   'RankCat_1': '293',
#   'ScoreCat_1': '6.67319',
#   'AmazonPrice': '$32.42'},
#  {'Title': 'Kingsburg (Second Edition) ',
#   'Link': 'https://boardgamegeek.com/boardgame/199966/kingsburg-second-edition',
#   'Rank': 980,
#   'Year': '2017',
#   'UsersRated': '3119',
#   'AveRating': '7.39399',
#   'Baverage': '6.61754',
#   'StdDev': '1.19266',
#   'AveWeight': '2.4512',
#   'NumWeights': '82',
#   'NumPlays': '6612',
#   'NumAwards': 0,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '40',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Dice Rolling\nTech Trees / Tech Tracks\nWorker Placement\nWorker Placement with Dice Workers\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '552',
#   'ScoreCat_1': '6.75526',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Spicy ',
#   'Link': 'https://boardgamegeek.com/boardgame/299169/spicy',
#   'Rank': 981,
#   'Year': '2020',
#   'UsersRated': '5116',
#   'AveRating': '7.16311',
#   'Baverage': '6.62876',
#   'StdDev': '1.3364',
#   'AveWeight': '1.3497',
#   'NumWeights': '183',
#   'NumPlays': '36094',
#   'NumAwards': 9,
#   'PCountRecomm_min': 3,
#   'PCountRecomm_max': 6,
#   'PCountBest_min': 4,
#   'PCountBest_max': 5,
#   'PCount_votes': '100',
#   'MinPlayTime': '15',
#   'MaxPlayTime': '20',
#   'Mechanics': 'Betting and Bluffing\nHand Management\n',
#   'Category_1': 'Party ',
#   'RankCat_1': '56',
#   'ScoreCat_1': '6.82177',
#   'AmazonPrice': '$17.85'},
#  {'Title': 'Faraway ',
#   'Link': 'https://boardgamegeek.com/boardgame/385761/faraway',
#   'Rank': 982,
#   'Year': '2023',
#   'UsersRated': '3555',
#   'AveRating': '7.57148',
#   'Baverage': '6.77107',
#   'StdDev': '1.19876',
#   'AveWeight': '1.8716',
#   'NumWeights': '109',
#   'NumPlays': '43123',
#   'NumAwards': 5,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 2,
#   'PCountBest_max': 3,
#   'PCount_votes': '75',
#   'MinPlayTime': '15',
#   'MaxPlayTime': '30',
#   'Mechanics': 'Contracts\nOpen Drafting\nSet Collection\nSimultaneous Action Selection\n',
#   'Category_1': 'Family ',
#   'RankCat_1': '163',
#   'ScoreCat_1': '6.93094',
#   'AmazonPrice': '$24.99'},
#  {'Title': 'The Vale of Eternity ',
#   'Link': 'https://boardgamegeek.com/boardgame/385529/the-vale-of-eternity',
#   'Rank': 983,
#   'Year': '2023',
#   'UsersRated': '3070',
#   'AveRating': '7.64257',
#   'Baverage': '6.74379',
#   'StdDev': '1.19805',
#   'AveWeight': '2.1075',
#   'NumWeights': '93',
#   'NumPlays': '16007',
#   'NumAwards': 1,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '96',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '45',
#   'Mechanics': 'Hand Management\nMarket\nOpen Drafting\nSet Collection\n',
#   'Category_1': 'Family ',
#   'RankCat_1': '168',
#   'ScoreCat_1': '6.9231',
#   'AmazonPrice': '$34.99'},
#  {'Title': 'Maharaja: The Game of Palace Building in India ',
#   'Link': 'https://boardgamegeek.com/boardgame/9440/maharaja-game-palace-building-india',
#   'Rank': 984,
#   'Year': '2004',
#   'UsersRated': '5091',
#   'AveRating': '7.10183',
#   'Baverage': '6.61654',
#   'StdDev': '1.29134',
#   'AveWeight': '3.1727',
#   'NumWeights': '579',
#   'NumPlays': '7566',
#   'NumAwards': 5,
#   'PCountRecomm_min': 3,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 5,
#   'PCount_votes': '102',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Area Majority / Influence\nNetwork and Route Building\nPoint to Point Movement\nSimultaneous Action Selection\nVariable Player Powers\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '582',
#   'ScoreCat_1': '6.71963',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Brew Crafters ',
#   'Link': 'https://boardgamegeek.com/boardgame/139898/brew-crafters',
#   'Rank': 985,
#   'Year': '2013',
#   'UsersRated': '3124',
#   'AveRating': '7.37669',
#   'Baverage': '6.61308',
#   'StdDev': '1.30714',
#   'AveWeight': '3.5817',
#   'NumWeights': '153',
#   'NumPlays': '7176',
#   'NumAwards': 0,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 3,
#   'PCountBest_max': 4,
#   'PCount_votes': '45',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '90',
#   'Mechanics': 'End Game Bonuses\nVariable Set-up\nWorker Placement\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '545',
#   'ScoreCat_1': '6.75821',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Bridge ',
#   'Link': 'https://boardgamegeek.com/boardgame/2181/bridge',
#   'Rank': 986,
#   'Year': '1925',
#   'UsersRated': '3126',
#   'AveRating': '7.45865',
#   'Baverage': '6.61572',
#   'StdDev': '2.00988',
#   'AveWeight': '3.891',
#   'NumWeights': '312',
#   'NumPlays': '26508',
#   'NumAwards': 0,
#   'PCountRecomm_min': 4,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '59',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '60',
#   'Mechanics': 'Hand Management\nPredictive Bid\nScore-and-Reset Game\nTeam-Based Game\nTrick-taking\nTurn Order: Claim Action\n',
#   'Category_1': 'Abstract ',
#   'RankCat_1': '42',
#   'ScoreCat_1': '6.91105',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '572',
#   'ScoreCat_2': '6.73844',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Orchard: A 9 card solitaire game ',
#   'Link': 'https://boardgamegeek.com/boardgame/245487/orchard-9-card-solitaire-game',
#   'Rank': 987,
#   'Year': '2018',
#   'UsersRated': '3421',
#   'AveRating': '7.34048',
#   'Baverage': '6.61302',
#   'StdDev': '1.17817',
#   'AveWeight': '1.1789',
#   'NumWeights': '95',
#   'NumPlays': '61696',
#   'NumAwards': 2,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 1,
#   'PCountBest_min': 1,
#   'PCountBest_max': 1,
#   'PCount_votes': '60',
#   'MinPlayTime': '5',
#   'MaxPlayTime': '10',
#   'Mechanics': 'Layering\nMelding and Splaying\nPattern Building\nSolo / Solitaire Game\nTile Placement\n',
#   'Category_1': 'Abstract ',
#   'RankCat_1': '39',
#   'ScoreCat_1': '6.95842',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Condottiere ',
#   'Link': 'https://boardgamegeek.com/boardgame/112/condottiere',
#   'Rank': 988,
#   'Year': '1995',
#   'UsersRated': '10229',
#   'AveRating': '6.87801',
#   'Baverage': '6.61731',
#   'StdDev': '1.33702',
#   'AveWeight': '1.9577',
#   'NumWeights': '732',
#   'NumPlays': '23970',
#   'NumAwards': 2,
#   'PCountRecomm_min': 3,
#   'PCountRecomm_max': 6,
#   'PCountBest_min': 4,
#   'PCountBest_max': 5,
#   'PCount_votes': '203',
#   'MinPlayTime': '20',
#   'MaxPlayTime': '45',
#   'Mechanics': 'Area Majority / Influence\nAuction/Bidding\nConstrained Bidding\nHand Management\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '639',
#   'ScoreCat_1': '6.6552',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Qwirkle ',
#   'Link': 'https://boardgamegeek.com/boardgame/25669/qwirkle',
#   'Rank': 989,
#   'Year': '2006',
#   'UsersRated': '20228',
#   'AveRating': '6.77367',
#   'Baverage': '6.61662',
#   'StdDev': '1.24618',
#   'AveWeight': '1.5893',
#   'NumWeights': '840',
#   'NumPlays': '90074',
#   'NumAwards': 14,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '205',
#   'MinPlayTime': '45',
#   'MaxPlayTime': '45',
#   'Mechanics': 'Hand Management\nPattern Building\nSquare Grid\nTile Placement\n',
#   'Category_1': 'Abstract ',
#   'RankCat_1': '90',
#   'ScoreCat_1': '6.60023',
#   'Category_2': 'Family ',
#   'RankCat_2': '321',
#   'ScoreCat_2': '6.63994',
#   'AmazonPrice': '$24.95'},
#  {'Title': 'Codex Naturalis ',
#   'Link': 'https://boardgamegeek.com/boardgame/314503/codex-naturalis',
#   'Rank': 990,
#   'Year': '2021',
#   'UsersRated': '4382',
#   'AveRating': '7.22945',
#   'Baverage': '6.62704',
#   'StdDev': '1.15063',
#   'AveWeight': '1.7451',
#   'NumWeights': '102',
#   'NumPlays': '26900',
#   'NumAwards': 5,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 2,
#   'PCountBest_max': 3,
#   'PCount_votes': '74',
#   'MinPlayTime': '20',
#   'MaxPlayTime': '30',
#   'Mechanics': 'Hand Management\nLayering\nPattern Building\n',
#   'Category_1': 'Family ',
#   'RankCat_1': '255',
#   'ScoreCat_1': '6.74718',
#   'AmazonPrice': '$23.34'},
#  {'Title': 'Dungeons & Dragons: Castle Ravenloft Board Game ',
#   'Link': 'https://boardgamegeek.com/boardgame/59946/dungeons-and-dragons-castle-ravenloft-board-game',
#   'Rank': 991,
#   'Year': '2010',
#   'UsersRated': '9276',
#   'AveRating': '6.9802',
#   'Baverage': '6.61493',
#   'StdDev': '1.43845',
#   'AveWeight': '2.5016',
#   'NumWeights': '614',
#   'NumPlays': '22500',
#   'NumAwards': 4,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '174',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '60',
#   'Mechanics': 'Cooperative Game\nDice Rolling\nGrid Movement\nModular Board\nRole Playing\nScenario / Mission / Campaign Game\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '267',
#   'ScoreCat_1': '6.69127',
#   'AmazonPrice': '$64.99'},
#  {'Title': 'Homesteaders ',
#   'Link': 'https://boardgamegeek.com/boardgame/26566/homesteaders',
#   'Rank': 992,
#   'Year': '2009',
#   'UsersRated': '3921',
#   'AveRating': '7.19143',
#   'Baverage': '6.61346',
#   'StdDev': '1.2317',
#   'AveWeight': '3.0391',
#   'NumWeights': '307',
#   'NumPlays': '10551',
#   'NumAwards': 1,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 4,
#   'PCountBest_max': 4,
#   'PCount_votes': '80',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Auction Compensation\nAuction: Fixed Placement\nAuction/Bidding\nConstrained Bidding\nIncome\nLoans\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '561',
#   'ScoreCat_1': '6.74551',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Tiny Epic Dinosaurs ',
#   'Link': 'https://boardgamegeek.com/boardgame/291508/tiny-epic-dinosaurs',
#   'Rank': 993,
#   'Year': '2020',
#   'UsersRated': '3586',
#   'AveRating': '7.32109',
#   'Baverage': '6.61991',
#   'StdDev': '1.18272',
#   'AveWeight': '2.6125',
#   'NumWeights': '80',
#   'NumPlays': '8851',
#   'NumAwards': 0,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '52',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '60',
#   'Mechanics': 'Contracts\nEnclosure\nHidden Victory Points\nSolo / Solitaire Game\nWorker Placement\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '580',
#   'ScoreCat_1': '6.72218',
#   'AmazonPrice': '$23.00'},
#  {'Title': 'The Others ',
#   'Link': 'https://boardgamegeek.com/boardgame/172047/the-others',
#   'Rank': 994,
#   'Year': '2016',
#   'UsersRated': '4063',
#   'AveRating': '7.31266',
#   'Baverage': '6.61319',
#   'StdDev': '1.57924',
#   'AveWeight': '3.0339',
#   'NumWeights': '118',
#   'NumPlays': '6934',
#   'NumAwards': 3,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 5,
#   'PCountBest_max': 5,
#   'PCount_votes': '89',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Area Majority / Influence\nArea Movement\nDice Rolling\nInterrupts\nModular Board\nTeam-Based Game\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '193',
#   'ScoreCat_1': '6.84713',
#   'AmazonPrice': '$79.99'},
#  {'Title': 'Thunder Alley ',
#   'Link': 'https://boardgamegeek.com/boardgame/108906/thunder-alley',
#   'Rank': 995,
#   'Year': '2014',
#   'UsersRated': '3595',
#   'AveRating': '7.29636',
#   'Baverage': '6.61391',
#   'StdDev': '1.49426',
#   'AveWeight': '2.3883',
#   'NumWeights': '206',
#   'NumPlays': '11201',
#   'NumAwards': 1,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 7,
#   'PCountBest_min': 4,
#   'PCountBest_max': 5,
#   'PCount_votes': '93',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Hand Management\nRace\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '192',
#   'ScoreCat_1': '6.84896',
#   'AmazonPrice': '$58.95'},
#  {'Title': 'Adrenaline ',
#   'Link': 'https://boardgamegeek.com/boardgame/202408/adrenaline',
#   'Rank': 996,
#   'Year': '2016',
#   'UsersRated': '6777',
#   'AveRating': '6.99231',
#   'Baverage': '6.61434',
#   'StdDev': '1.28216',
#   'AveWeight': '2.3851',
#   'NumWeights': '148',
#   'NumPlays': '13892',
#   'NumAwards': 5,
#   'PCountRecomm_min': 3,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 4,
#   'PCountBest_max': 5,
#   'PCount_votes': '108',
#   'MinPlayTime': '30',
#   'MaxPlayTime': '60',
#   'Mechanics': 'Action Points\nGrid Movement\nHand Management\nKill Steal\nOpen Drafting\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '243',
#   'ScoreCat_1': '6.74414',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '614',
#   'ScoreCat_2': '6.68013',
#   'AmazonPrice': '$53.38'},
#  {'Title': 'Tidal Blades: Heroes of the Reef ',
#   'Link': 'https://boardgamegeek.com/boardgame/233262/tidal-blades-heroes-reef',
#   'Rank': 997,
#   'Year': '2020',
#   'UsersRated': '2941',
#   'AveRating': '7.49484',
#   'Baverage': '6.61144',
#   'StdDev': '1.46058',
#   'AveWeight': '2.9125',
#   'NumWeights': '80',
#   'NumPlays': '6820',
#   'NumAwards': 2,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 3,
#   'PCountBest_max': 3,
#   'PCount_votes': '76',
#   'MinPlayTime': '60',
#   'MaxPlayTime': '90',
#   'Mechanics': 'Dice Rolling\nHand Management\nKill Steal\nOpen Drafting\nRe-rolling and Locking\nSet Collection\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '569',
#   'ScoreCat_1': '6.74059',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'DinoGenics ',
#   'Link': 'https://boardgamegeek.com/boardgame/210296/dinogenics',
#   'Rank': 998,
#   'Year': '2019',
#   'UsersRated': '2414',
#   'AveRating': '7.6145',
#   'Baverage': '6.61086',
#   'StdDev': '1.43318',
#   'AveWeight': '2.9259',
#   'NumWeights': '81',
#   'NumPlays': '8266',
#   'NumAwards': 2,
#   'PCountRecomm_min': 1,
#   'PCountRecomm_max': 5,
#   'PCountBest_min': 3,
#   'PCountBest_max': 4,
#   'PCount_votes': '63',
#   'MinPlayTime': '90',
#   'MaxPlayTime': '120',
#   'Mechanics': 'Dice Rolling\nEvents\nHand Management\nSet Collection\nSolo / Solitaire Game\nTile Placement\n',
#   'Category_1': 'Thematic',
#   'RankCat_1': '158',
#   'ScoreCat_1': '6.93297',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '534',
#   'ScoreCat_2': '6.77118',
#   'AmazonPrice': 'Unknown'},
#  {'Title': 'Virgin Queen ',
#   'Link': 'https://boardgamegeek.com/boardgame/41066/virgin-queen',
#   'Rank': 999,
#   'Year': '2012',
#   'UsersRated': '1753',
#   'AveRating': '8.0031',
#   'Baverage': '6.60837',
#   'StdDev': '1.64639',
#   'AveWeight': '4.4384',
#   'NumWeights': '219',
#   'NumPlays': '3038',
#   'NumAwards': 2,
#   'PCountRecomm_min': 4,
#   'PCountRecomm_max': 6,
#   'PCountBest_min': 6,
#   'PCountBest_max': 6,
#   'PCount_votes': '74',
#   'MinPlayTime': '420',
#   'MaxPlayTime': '420',
#   'Mechanics': 'Campaign / Battle Card Driven\nDice Rolling\nPoint to Point Movement\nSimulation\nVariable Phase Order\nVariable Player Powers\n',
#   'Category_1': 'War ',
#   'RankCat_1': '23',
#   'ScoreCat_1': '7.60148',
#   'Category_2': 'Strategy ',
#   'RankCat_2': '504',
#   'ScoreCat_2': '6.80141',
#   'AmazonPrice': '$129.95'},
#  {'Title': 'Attika ',
#   'Link': 'https://boardgamegeek.com/boardgame/8051/attika',
#   'Rank': 1000,
#   'Year': '2003',
#   'UsersRated': '6609',
#   'AveRating': '6.98899',
#   'Baverage': '6.60954',
#   'StdDev': '1.25247',
#   'AveWeight': '2.3662',
#   'NumWeights': '822',
#   'NumPlays': '24950',
#   'NumAwards': 5,
#   'PCountRecomm_min': 2,
#   'PCountRecomm_max': 4,
#   'PCountBest_min': 2,
#   'PCountBest_max': 2,
#   'PCount_votes': '206',
#   'MinPlayTime': '45',
#   'MaxPlayTime': '60',
#   'Mechanics': 'Map Addition\nModular Board\nNetwork and Route Building\nTile Placement\n',
#   'Category_1': 'Strategy ',
#   'RankCat_1': '607',
#   'ScoreCat_1': '6.69085',
#   'AmazonPrice': 'Unknown'},
#  ...]

# %%
# Save the DataFrame to a CSV file
df.to_csv('bgg_data_2300_2024-05.csv', index=False)

# %%
import requests

# Define the base URL and parameters
base_url = "https://api.geekdo.com/api/amazon"
endpoints = ["textads", "itemurls"]
params = {
    "locale": "us",
    "objectid": "224517",
    "objecttype": "thing"
}

# Loop over the endpoints and make requests
for endpoint in endpoints:
    url = f"{base_url}/{endpoint}"
    response = requests.get(url, params=params)
    
    if response.status_code == 200:
        data = response.json()  # Parse the JSON response
        print(f"Data from {endpoint}:")
        print(data)  # Print the parsed JSON, or extract specific data as needed
    else:
        print(f"Failed to fetch data from {endpoint}. Server responded with status code {response.status_code}")
# Out:
# Data from textads:
# {'us': {'sponsorname': 'Amazon', 'supersaver': False, 'prime': False, 'title': 'Get Brass: Birmingham on Amazon $79.95', 'defaultprice': '$79.95', 'newprice': '$79.95', 'listprice': None, 'url': 'https://www.amazon.com/dp/1988884047?tag=itemtext-boardgamegeek-20&linkCode=ogi&th=1&psc=1', 'sponsorurl': 'https://www.amazon.com/dp/1988884047?tag=itemtext-boardgamegeek-20&linkCode=ogi&th=1&psc=1', 'add_to_cart_url': 'https://www.amazon.com/gp/aws/cart/add.html?AssociateTag=itemtext-boardgamegeek-20&ASIN.1=1988884047'}}
# Data from itemurls:
# {'us': '//ws-na.amazon-adsystem.com/widgets/q?ServiceVersion=20070822&OneJS=1&Operation=GetAdHtml&MarketPlace=US&source=ac&ref=tf_til&ad_type=product_link&tracking_id=boardgamegeek-20&marketplace=amazon&region=US&placement=1988884047&asins=1988884047&show_border=false&link_opens_in_new_window=true'}

# %%
listurls.index(url)
# Out:
# 1014

# %%
# Initialize an empty list to store the data
#data_list = []

# Sample list of URLs (replace with your actual list of 2003 URLs)
#listurls = ['https://boardgamegeek.com/boardgame/161936/pandemic-legacy-season-1']

lasturl = url

# Sample headers (replace with your actual headers)
headers = {'User-Agent': 'Mozilla/5.0'}

initiate = False
for url in listurls:
    if url == lasturl:
        initiate = True
    
    if initiate:
        # Initialize a dictionary to store the data for each game
        game_data = {}
        
        page = requests.get(url, headers=headers)
        soup = BeautifulSoup(page.content, "html.parser")

        # Extract objectid from the URL
        objectid = url.split('/')[-2]

        # Title
        title_tag = soup.find('title')
        title_text = title_tag.text.split('|')[0] if title_tag else 'Unknown'
        game_data['Title'] = title_text  # Store in dictionary
        
        # Year published
        json_data_match = re.search(r'GEEK\.geekitemPreload = ({.*?});', str(soup))
        
        # Parse the JSON data if found
        if json_data_match:
            json_data_str = json_data_match.group(1)
            
            try:
                json_data = json.loads(json_data_str)
                
                game_data['Link'] = url

                ## Exploration of data follows Ranking
                game_data['Rank'] = rank  # Store in dictionary 

                # Extract the publishing year
                year_published = json_data.get('item', {}).get('yearpublished', 'Unknown')
                game_data['Year'] = year_published  # Store in dictionary
                
                # Extract additional game info
                stats = json_data.get('item', {}).get('stats', {})
                game_data['UsersRated'] = stats.get('usersrated', 'Unknown')
                game_data['AveRating'] = stats.get('average', 'Unknown')
                game_data['Baverage'] = stats.get('baverage', 'Unknown')
                game_data['StdDev'] = stats.get('stddev', 'Unknown')
                game_data['AveWeight'] = stats.get('avgweight', 'Unknown')
                game_data['NumWeights'] = stats.get('numweights', 'Unknown')
                game_data['NumPlays'] = stats.get('numplays', 'Unknown')
                
                linkcounts = json_data.get('item', {}).get('linkcounts', {})
                game_data['NumAwards'] = linkcounts.get('boardgamehonor', 0)

                polls = json_data.get('item', {}).get('polls', {})
                #print( polls.get('userplayers', 'Unknown')['totalvotes'] )
                game_data['PCountRecomm_min'] = polls.get('userplayers', 'Unknown')['recommended'][0]['min']
                game_data['PCountRecomm_max'] = polls.get('userplayers', 'Unknown')['recommended'][0]['max']
                game_data['PCountBest_min'] = polls.get('userplayers', 'Unknown')['best'][0]['min']
                game_data['PCountBest_max'] = polls.get('userplayers', 'Unknown')['best'][0]['max']
                game_data['PCount_votes'] = polls.get('userplayers', 'Unknown')['totalvotes']

                game_data['MinPlayTime'] = json_data.get('item', {}).get('minplaytime', 'NA')
                game_data['MaxPlayTime'] = json_data.get('item', {}).get('maxplaytime', 'NA')

                mechanics = json_data.get('item', {}).get('links', {}).get('boardgamemechanic', [])
                mechstring = ''
                for i, mech in enumerate(mechanics):
                    mechstring += mech['name']
                    if i < len(mech)-1:
                        mechstring += '\n'
                game_data['Mechanics'] = mechstring
                
                rankinfo = json_data.get('item', {}).get('rankinfo', [])
                for i, rinf in enumerate(rankinfo):
                    if rinf['prettyname'] != 'Board Game Rank':
                        game_data['Category_'+str(i)] = rinf['veryshortprettyname']
                        game_data['RankCat_'+str(i)] = rinf['rank']
                        game_data['ScoreCat_'+str(i)] = rinf['baverage']
                
                rank += 1
            except json.JSONDecodeError as e:
                print(f"JSONDecodeError: {e}")
        else:
            print("JSON data not found in HTML content.")
        
        ############## AMAZON price ##############
        # Define the base URL and parameters for Amazon price
        amazon_url = "https://api.geekdo.com/api/amazon/textads"
        params = {
            "locale": "us",
            "objectid": objectid,
            "objecttype": "thing"
        }
        # Make a request to the Amazon API endpoint
        response = requests.get(amazon_url, params=params)
        if response.status_code == 200:
            amazon_data = response.json()
            if isinstance(amazon_data, dict):  # Check if the response is a dictionary
                price = amazon_data.get('us', {}).get('newprice', 'Unknown')
            else:
                price = 'Unknown'
            game_data['AmazonPrice'] = price

        else:
            game_data['AmazonPrice'] = 'Unknown'
        ############################################

        # Append the game data to the list
        data_list.append(game_data)

    # Uncomment the following line to exit the loop for testing
    # sys.exit()

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(data_list)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 66
#      64 polls = json_data.get('item', {}).get('polls', {})
#      65 #print( polls.get('userplayers', 'Unknown')['totalvotes'] )
# ---> 66 game_data['PCountRecomm_min'] = polls.get('userplayers', 'Unknown')['recommended'][0]['min']
#      67 game_data['PCountRecomm_max'] = polls.get('userplayers', 'Unknown')['recommended'][0]['max']
#      68 game_data['PCountBest_min'] = polls.get('userplayers', 'Unknown')['best'][0]['min']
#
# IndexError: list index out of range

# %%
df
# Out:
#                                                   Title  \
# 0                                    Brass: Birmingham
# 1                            Pandemic Legacy: Season 1
# 2                                           Gloomhaven
# 3                                             Ark Nova
# 4                    Twilight Imperium: Fourth Edition
# ...                                                 ...
# 3308                                        Whoowasit?
# 3309                                     Small Islands
# 3310                        The Blood of an Englishman
# 3311  Panzer: The Game of Small Unit Actions and Com...
# 3312                                      Dancing Eggs
#
#                                                    Link  Rank  Year  \
# 0     https://boardgamegeek.com/boardgame/224517/bra...     1  2018
# 1     https://boardgamegeek.com/boardgame/161936/pan...     2  2015
# 2     https://boardgamegeek.com/boardgame/174430/glo...     3  2017
# 3     https://boardgamegeek.com/boardgame/342942/ark...     4  2021
# 4     https://boardgamegeek.com/boardgame/233078/twi...     5  2017
# ...                                                 ...   ...   ...
# 3308  https://boardgamegeek.com/boardgame/33643/whoo...  3309  2007
# 3309  https://boardgamegeek.com/boardgame/236248/sma...  3310  2018
# 3310  https://boardgamegeek.com/boardgame/206504/blo...  3311  2016
# 3311  https://boardgamegeek.com/boardgame/85769/panz...  3312  2012
# 3312  https://boardgamegeek.com/boardgame/8924/danci...  3313  2003
#
#      UsersRated AveRating Baverage   StdDev AveWeight NumWeights  ...  \
# 0         46043   8.59731  8.41456  1.41606    3.8789       2229  ...
# 1         53558   8.52713  8.37875   1.5984    2.8316       1461  ...
# 2         62246   8.58836  8.35218  1.73928    3.9115       2566  ...
# 3         43695   8.53514  8.33503  1.38399    3.7606       2297  ...
# 4         23849   8.60087  8.24171  1.62048     4.319       1166  ...
# ...         ...       ...      ...      ...       ...        ...  ...
# 3308       1094   6.80182  5.92831  1.50822    1.4561         57  ...
# 3309       1380   6.62765  5.92564  1.34981    2.0455         44  ...
# 3310       1496   6.54979  5.92681  1.23373    1.8261         23  ...
# 3311        553   7.85953  5.92759  1.47996    3.7536         69  ...
# 3312       2369   6.32233  5.92755  1.44353    1.0485        165  ...
#
#        Category_1  RankCat_1  ScoreCat_1  AmazonPrice  Category_2  RankCat_2  \
# 0       Strategy           1     8.43113       $63.48         NaN        NaN
# 1        Thematic          1     8.37923       $71.97   Strategy           2
# 2        Thematic          2     8.33121      $285.49   Strategy           4
# 3       Strategy           3      8.3448       $56.92         NaN        NaN
# 4        Thematic          3     8.26231      $131.99   Strategy           5
# ...           ...        ...         ...          ...         ...        ...
# 3308  Children's          30     6.61902      Unknown         NaN        NaN
# 3309      Family        1066     6.01504      Unknown         NaN        NaN
# 3310      Family        1050      6.0255       $16.19         NaN        NaN
# 3311         War         192     6.93608      Unknown         NaN        NaN
# 3312  Children's          90     6.21871       $45.00      Party         249
#
#      ScoreCat_2 Category_3 RankCat_3 ScoreCat_3
# 0           NaN        NaN       NaN        NaN
# 1        8.3668        NaN       NaN        NaN
# 2       8.31405        NaN       NaN        NaN
# 3           NaN        NaN       NaN        NaN
# 4       8.26381        NaN       NaN        NaN
# ...         ...        ...       ...        ...
# 3308        NaN        NaN       NaN        NaN
# 3309        NaN        NaN       NaN        NaN
# 3310        NaN        NaN       NaN        NaN
# 3311        NaN        NaN       NaN        NaN
# 3312    6.09855        NaN       NaN        NaN
#
# [3313 rows x 30 columns]

# %%
df = pd.DataFrame(data_list)

# %%
name = f'bgg_data_0-{1000}.pkl'
print('Name of pickle file:')
print(name)

df.to_pickle(name)
# Out:
# Name of pickle file:
# bgg_data_0-1000.pkl

# %%
(df
 .query('PCountBest_min > 4')
 .query('PCountBest_max < 7')
)
# Out:
#                                        Title  \
# 4         Twilight Imperium: Fourth Edition
# 41                 Heat: Pedal to the Metal
# 91                                El Grande
# 94     Battlestar Galactica: The Board Game
# 114        Twilight Imperium: Third Edition
# ...                                      ...
# 3272                   Formula Motor Racing
# 3291           A Brief History of the World
# 3292                   Ghost Blitz: 5 to 12
# 3305                             Valparaíso
# 3307  Dungeons & Dragons: Rock Paper Wizard
#
#                                                    Link  Rank  Year  \
# 4     https://boardgamegeek.com/boardgame/233078/twi...     5  2017
# 41    https://boardgamegeek.com/boardgame/366013/hea...    42  2022
# 91     https://boardgamegeek.com/boardgame/93/el-grande    92  1995
# 94    https://boardgamegeek.com/boardgame/37111/batt...    95  2008
# 114   https://boardgamegeek.com/boardgame/12493/twil...   115  2005
# ...                                                 ...   ...   ...
# 3272  https://boardgamegeek.com/boardgame/635/formul...  3273  1995
# 3291  https://boardgamegeek.com/boardgame/46007/brie...  3292  2009
# 3292  https://boardgamegeek.com/boardgame/148532/gho...  3293  2013
# 3305  https://boardgamegeek.com/boardgame/257058/val...  3306  2018
# 3307  https://boardgamegeek.com/boardgame/207062/dun...  3308  2016
#
#      UsersRated AveRating Baverage   StdDev AveWeight NumWeights  ...  \
# 4         23849   8.60087  8.24171  1.62048     4.319       1166  ...
# 41        22984   8.07355  7.79997  1.31027     2.196        658  ...
# 91        29011   7.75581  7.57689  1.33082    2.9705       2342  ...
# 94        36538   7.73001  7.53881  1.59626    3.2499       2213  ...
# 114       19287   7.79287  7.49565  1.71749     4.258       2085  ...
# ...         ...       ...      ...      ...       ...        ...  ...
# 3272       2005   6.40748  5.93716  1.29191    1.1801        211  ...
# 3291        948    6.8629  5.92966  1.43616    2.8681         91  ...
# 3292       1030   6.93647  5.93023  1.40416     1.303         33  ...
# 3305        952   6.87959  5.92737  1.12636    2.8049         41  ...
# 3307       1530   6.57288  5.93244  1.36025    1.3333         27  ...
#
#      Category_1  RankCat_1  ScoreCat_1  AmazonPrice  Category_2  RankCat_2  \
# 4      Thematic          3     8.26231      $131.99   Strategy           5
# 41      Family           4     7.83387       $74.99         NaN        NaN
# 91    Strategy          82     7.60759      Unknown         NaN        NaN
# 94     Thematic         32     7.54329      Unknown         NaN        NaN
# 114    Thematic         33     7.54016      $195.00   Strategy         113
# ...         ...        ...         ...          ...         ...        ...
# 3272    Family        1079     6.00725      Unknown         NaN        NaN
# 3291  Strategy        1436     6.04148      Unknown         NaN        NaN
# 3292     Party         171     6.30006      Unknown         NaN        NaN
# 3305  Strategy        1450      6.0343       $48.95         NaN        NaN
# 3307     Party         223     6.16784       $21.72         NaN        NaN
#
#      ScoreCat_2 Category_3 RankCat_3 ScoreCat_3
# 4       8.26381        NaN       NaN        NaN
# 41          NaN        NaN       NaN        NaN
# 91          NaN        NaN       NaN        NaN
# 94          NaN        NaN       NaN        NaN
# 114     7.50412        NaN       NaN        NaN
# ...         ...        ...       ...        ...
# 3272        NaN        NaN       NaN        NaN
# 3291        NaN        NaN       NaN        NaN
# 3292        NaN        NaN       NaN        NaN
# 3305        NaN        NaN       NaN        NaN
# 3307        NaN        NaN       NaN        NaN
#
# [263 rows x 30 columns]

# %%
# Out:
# Empty DataFrame
# Columns: [Title, Link, Rank, Year, UsersRated, AveRating, Baverage, StdDev, AveWeight, NumWeights, NumPlays, NumAwards, PCountRecomm_min, PCountRecomm_max, PCountBest_min, PCountBest_max, PCount_votes, MinPlayTime, MaxPlayTime, Mechanics, Category_1, RankCat_1, ScoreCat_1, AmazonPrice, Category_2, RankCat_2, ScoreCat_2, Category_3, RankCat_3, ScoreCat_3]
# Index: []
#
# [0 rows x 30 columns]
